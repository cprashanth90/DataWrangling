# %% [markdown]
# ### WeRateDogs Twitter Archive

# %% [markdown]
# The goal of this project is to wrangle and analyze the tweets and retweet counts of dog ratings data. WeRateDogs is a great archive, but appears to contain very basic information with regard to the tweet counts, etc..
#
# The missing tweet stats can be completed by making use of the Twitter API where we can query for a given tweet ID and Twitter API will return us a JSON data with other information regarding the tweet.
#
# We are also provided with image predictions of what breed a particular dog belongs to, in a separate file on image_predictions.tsv. These predictions are run using a Neural network.

# %% [markdown]
# Below we first import the necessary libraries for the data wrangling exercise

# %%
import pandas as pd
import numpy as np
import csv
import json
import requests
import tweepy
import re
from wrangle_utils import *

# %% [markdown]
# #### NOTE on helper methods and utilities:
#
# All methods that are used by this notebook are defined in file wrangle_utils.py saved in the same archive.

# %% [markdown]
# ### Data that we have:

# %% [markdown]
# We are already provided with the following datasets:
# 1. Tweet data from the WerateDogs Twitter Archive - in a .csv file (twitter-archive-enhanced.csv).
# 2. Predictions from a neural network model that details predictions of dog breed and the score of the predictions. This is from a tsv file saved at "https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv"
#
# First I am going to get the data that we already have. Then, later for the missing information and tweet info, we can make use of the tweepy library to get tweet data from twitter.

# %% [markdown]
# ### Gathering Data - Initial steps

# %%
weratedogs_twitter_archive_data = pd.read_csv("twitter-archive-enhanced.csv")

# %%
url = "https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv"
predictions = get_predictions_file(url)

# %%
predictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null object
# jpg_url     2075 non-null object
# img_num     2075 non-null object
# p1          2075 non-null object
# p1_conf     2075 non-null object
# p1_dog      2075 non-null object
# p2          2075 non-null object
# p2_conf     2075 non-null object
# p2_dog      2075 non-null object
# p3          2075 non-null object
# p3_conf     2075 non-null object
# p3_dog      2075 non-null object
# dtypes: object(12)
# memory usage: 194.6+ KB

# %% [markdown]
# ## Assessing Data

# %% [markdown]
# Here is a snapshot of the first few rows in the dataset.

# %%
weratedogs_twitter_archive_data.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3  This is Darla. She commenced a snooze mid meal...                  NaN
# 4  This is Franklin. He would like you to stop ca...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name doggo floofer pupper puppo
# 0                  10   Phineas  None    None   None  None
# 1                  10     Tilly  None    None   None  None
# 2                  10    Archie  None    None   None  None
# 3                  10     Darla  None    None   None  None
# 4                  10  Franklin  None    None   None  None

# %% [markdown]
# Now let's check for Null values in the twitter_archive data.
# From visual inspection of the .csv file, we find that one of the columns that has got null values is the 'expanded_urls' column. 59 null values in the expanded_urls column.

# %%
weratedogs_twitter_archive_data[weratedogs_twitter_archive_data.expanded_urls.isnull()].shape
# Out:
# (59, 17)

# %%
weratedogs_twitter_archive_data[weratedogs_twitter_archive_data.expanded_urls.isnull()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 30    886267009285017600           8.862664e+17         2.281182e+09
# 55    881633300179243008           8.816070e+17         4.738443e+07
# 64    879674319642796034           8.795538e+17         3.105441e+09
# 113   870726314365509632           8.707262e+17         1.648776e+07
# 148   863427515083354112           8.634256e+17         7.759620e+07
# 179   857214891891077121           8.571567e+17         1.806710e+08
# 185   856330835276025856                    NaN                  NaN
# 186   856288084350160898           8.562860e+17         2.792810e+08
# 188   855862651834028034           8.558616e+17         1.943518e+08
# 189   855860136149123072           8.558585e+17         1.361572e+07
# 218   850333567704068097           8.503288e+17         2.195506e+07
# 228   848213670039564288           8.482121e+17         4.196984e+09
# 234   847617282490613760           8.476062e+17         4.196984e+09
# 274   840698636975636481           8.406983e+17         8.405479e+17
# 290   838150277551247360           8.381455e+17         2.195506e+07
# 291   838085839343206401           8.380855e+17         2.894131e+09
# 313   835246439529840640           8.352460e+17         2.625958e+07
# 342   832088576586297345           8.320875e+17         3.058208e+07
# 346   831926988323639298           8.319030e+17         2.068372e+07
# 375   828361771580813312                    NaN                  NaN
# 387   826598799820865537           8.265984e+17         4.196984e+09
# 409   823333489516937216           8.233264e+17         1.582854e+09
# 427   821153421864615936           8.211526e+17         1.132119e+08
# 498   813130366689148928           8.131273e+17         4.196984e+09
# 513   811647686436880384           8.116272e+17         4.196984e+09
# 570   801854953262350336           8.018543e+17         1.185634e+07
# 576   800859414831898624           8.008580e+17         2.918590e+08
# 611   797165961484890113           7.971238e+17         2.916630e+07
# 701   786051337297522688           7.727430e+17         7.305050e+17
# 707   785515384317313025                    NaN                  NaN
# 843   766714921925144576           7.667118e+17         4.196984e+09
# 857   763956972077010945           7.638652e+17         1.584641e+07
# 967   750381685133418496           7.501805e+17         4.717297e+09
# 1005  747651430853525504           7.476487e+17         4.196984e+09
# 1080  738891149612572673           7.384119e+17         3.589728e+08
# 1295  707983188426153984           7.079801e+17         2.319108e+09
# 1345  704491224099647488           7.044857e+17         2.878549e+07
# 1445  696518437233913856                    NaN                  NaN
# 1446  696490539101908992           6.964887e+17         4.196984e+09
# 1474  693644216740769793           6.936422e+17         4.196984e+09
# 1479  693582294167244802           6.935722e+17         1.198989e+09
# 1497  692423280028966913           6.924173e+17         4.196984e+09
# 1523  690607260360429569           6.903413e+17         4.670367e+08
# 1598  686035780142297088           6.860340e+17         4.196984e+09
# 1605  685681090388975616           6.855479e+17         4.196984e+09
# 1618  684969860808454144           6.849598e+17         4.196984e+09
# 1663  682808988178739200           6.827884e+17         4.196984e+09
# 1689  681340665377193984           6.813394e+17         4.196984e+09
# 1774  678023323247357953           6.780211e+17         4.196984e+09
# 1819  676590572941893632           6.765883e+17         4.196984e+09
# 1844  675849018447167488           6.758457e+17         4.196984e+09
# 1895  674742531037511680           6.747400e+17         4.196984e+09
# 1905  674606911342424069           6.744689e+17         4.196984e+09
# 1914  674330906434379776           6.658147e+17         1.637468e+07
# 1940  673716320723169284           6.737159e+17         4.196984e+09
# 2038  671550332464455680           6.715449e+17         4.196984e+09
# 2149  669684865554620416           6.693544e+17         4.196984e+09
# 2189  668967877119254528           6.689207e+17         2.143566e+07
# 2298  667070482143944705           6.670655e+17         4.196984e+09
#
#                       timestamp  \
# 30    2017-07-15 16:51:35 +0000
# 55    2017-07-02 21:58:53 +0000
# 64    2017-06-27 12:14:36 +0000
# 113   2017-06-02 19:38:25 +0000
# 148   2017-05-13 16:15:35 +0000
# 179   2017-04-26 12:48:51 +0000
# 185   2017-04-24 02:15:55 +0000
# 186   2017-04-23 23:26:03 +0000
# 188   2017-04-22 19:15:32 +0000
# 189   2017-04-22 19:05:32 +0000
# 218   2017-04-07 13:04:55 +0000
# 228   2017-04-01 16:41:12 +0000
# 234   2017-03-31 01:11:22 +0000
# 274   2017-03-11 22:59:09 +0000
# 290   2017-03-04 22:12:52 +0000
# 291   2017-03-04 17:56:49 +0000
# 313   2017-02-24 21:54:03 +0000
# 342   2017-02-16 04:45:50 +0000
# 346   2017-02-15 18:03:45 +0000
# 375   2017-02-05 21:56:51 +0000
# 387   2017-02-01 01:11:25 +0000
# 409   2017-01-23 00:56:15 +0000
# 427   2017-01-17 00:33:26 +0000
# 498   2016-12-25 21:12:41 +0000
# 513   2016-12-21 19:01:02 +0000
# 570   2016-11-24 18:28:13 +0000
# 576   2016-11-22 00:32:18 +0000
# 611   2016-11-11 19:55:50 +0000
# 701   2016-10-12 03:50:17 +0000
# 707   2016-10-10 16:20:36 +0000
# 843   2016-08-19 19:14:16 +0000
# 857   2016-08-12 04:35:10 +0000
# 967   2016-07-05 17:31:49 +0000
# 1005  2016-06-28 04:42:46 +0000
# 1080  2016-06-04 00:32:32 +0000
# 1295  2016-03-10 17:35:20 +0000
# 1345  2016-03-01 02:19:31 +0000
# 1445  2016-02-08 02:18:30 +0000
# 1446  2016-02-08 00:27:39 +0000
# 1474  2016-01-31 03:57:23 +0000
# 1479  2016-01-30 23:51:19 +0000
# 1497  2016-01-27 19:05:49 +0000
# 1523  2016-01-22 18:49:36 +0000
# 1598  2016-01-10 04:04:10 +0000
# 1605  2016-01-09 04:34:45 +0000
# 1618  2016-01-07 05:28:35 +0000
# 1663  2016-01-01 06:22:03 +0000
# 1689  2015-12-28 05:07:27 +0000
# 1774  2015-12-19 01:25:31 +0000
# 1819  2015-12-15 02:32:17 +0000
# 1844  2015-12-13 01:25:37 +0000
# 1895  2015-12-10 00:08:50 +0000
# 1905  2015-12-09 15:09:55 +0000
# 1914  2015-12-08 20:53:11 +0000
# 1940  2015-12-07 04:11:02 +0000
# 2038  2015-12-01 04:44:10 +0000
# 2149  2015-11-26 01:11:28 +0000
# 2189  2015-11-24 01:42:25 +0000
# 2298  2015-11-18 20:02:51 +0000
#
#                                                  source  \
# 30    <a href="http://twitter.com/download/iphone" r...
# 55    <a href="http://twitter.com/download/iphone" r...
# 64    <a href="http://twitter.com/download/iphone" r...
# 113   <a href="http://twitter.com/download/iphone" r...
# 148   <a href="http://twitter.com/download/iphone" r...
# 179   <a href="http://twitter.com/download/iphone" r...
# 185   <a href="http://twitter.com/download/iphone" r...
# 186   <a href="http://twitter.com/download/iphone" r...
# 188   <a href="http://twitter.com/download/iphone" r...
# 189   <a href="http://twitter.com/download/iphone" r...
# 218   <a href="http://twitter.com/download/iphone" r...
# 228   <a href="http://twitter.com/download/iphone" r...
# 234   <a href="http://twitter.com/download/iphone" r...
# 274   <a href="http://twitter.com/download/iphone" r...
# 290   <a href="http://twitter.com/download/iphone" r...
# 291   <a href="http://twitter.com/download/iphone" r...
# 313   <a href="http://twitter.com/download/iphone" r...
# 342   <a href="http://twitter.com/download/iphone" r...
# 346   <a href="http://twitter.com/download/iphone" r...
# 375   <a href="http://twitter.com" rel="nofollow">Tw...
# 387   <a href="http://twitter.com/download/iphone" r...
# 409   <a href="http://twitter.com/download/iphone" r...
# 427   <a href="http://twitter.com/download/iphone" r...
# 498   <a href="http://twitter.com/download/iphone" r...
# 513   <a href="http://twitter.com/download/iphone" r...
# 570   <a href="http://twitter.com/download/iphone" r...
# 576   <a href="http://twitter.com/download/iphone" r...
# 611   <a href="http://twitter.com/download/iphone" r...
# 701   <a href="http://twitter.com/download/iphone" r...
# 707   <a href="http://twitter.com/download/iphone" r...
# 843   <a href="http://twitter.com/download/iphone" r...
# 857   <a href="http://twitter.com/download/iphone" r...
# 967   <a href="http://twitter.com/download/iphone" r...
# 1005  <a href="http://twitter.com/download/iphone" r...
# 1080  <a href="http://twitter.com/download/iphone" r...
# 1295  <a href="http://twitter.com/download/iphone" r...
# 1345  <a href="http://twitter.com/download/iphone" r...
# 1445  <a href="http://twitter.com/download/iphone" r...
# 1446  <a href="http://twitter.com/download/iphone" r...
# 1474  <a href="http://twitter.com/download/iphone" r...
# 1479  <a href="http://twitter.com/download/iphone" r...
# 1497  <a href="http://twitter.com/download/iphone" r...
# 1523  <a href="http://twitter.com/download/iphone" r...
# 1598  <a href="http://twitter.com/download/iphone" r...
# 1605  <a href="http://twitter.com/download/iphone" r...
# 1618  <a href="http://twitter.com/download/iphone" r...
# 1663  <a href="http://twitter.com/download/iphone" r...
# 1689  <a href="http://twitter.com/download/iphone" r...
# 1774  <a href="http://twitter.com/download/iphone" r...
# 1819  <a href="http://twitter.com/download/iphone" r...
# 1844  <a href="http://twitter.com/download/iphone" r...
# 1895  <a href="http://twitter.com/download/iphone" r...
# 1905  <a href="http://twitter.com/download/iphone" r...
# 1914  <a href="http://twitter.com/download/iphone" r...
# 1940  <a href="http://twitter.com/download/iphone" r...
# 2038  <a href="http://twitter.com/download/iphone" r...
# 2149  <a href="http://twitter.com/download/iphone" r...
# 2189  <a href="http://twitter.com/download/iphone" r...
# 2298  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 30    @NonWhiteHat @MayhewMayhem omg hello tanner yo...                  NaN
# 55    @roushfenway These are good dogs but 17/10 is ...                  NaN
# 64                      @RealKentMurphy 14/10 confirmed                  NaN
# 113   @ComplicitOwl @ShopWeRateDogs &gt;10/10 is res...                  NaN
# 148   @Jack_Septic_Eye I'd need a few more pics to p...                  NaN
# 179                        @Marc_IRL pixelated af 12/10                  NaN
# 185   RT @Jenna_Marbles: @dog_rates Thanks for ratin...         8.563302e+17
# 186   @xianmcguire @Jenna_Marbles Kardashians wouldn...                  NaN
# 188   @dhmontgomery We also gave snoop dogg a 420/10...                  NaN
# 189   @s8n You tried very hard to portray this good ...                  NaN
# 218   @markhoppus MARK THAT DOG HAS SEEN AND EXPERIE...                  NaN
# 228   Jerry just apuppologized to me. He said there ...                  NaN
# 234   .@breaannanicolee PUPDATE: Cannon has a heart ...                  NaN
# 274   @0_kelvin_0 &gt;10/10 is reserved for puppos s...                  NaN
# 290                                  @markhoppus 182/10                  NaN
# 291   @bragg6of8 @Andy_Pace_ we are still looking fo...                  NaN
# 313   @jonnysun @Lin_Manuel ok jomny I know you're e...                  NaN
# 342            @docmisterio account started on 11/15/15                  NaN
# 346                              @UNC can confirm 12/10                  NaN
# 375   Beebop and Doobert should start a band 12/10 w...                  NaN
# 387   I was going to do 007/10, but the joke wasn't ...                  NaN
# 409                                @HistoryInPics 13/10                  NaN
# 427   @imgur for a polar bear tho I'd say 13/10 is a...                  NaN
# 498   I've been informed by multiple sources that th...                  NaN
# 513   PUPDATE: I've been informed that Augie was act...                  NaN
# 570   .@NBCSports OMG THE TINY HAT I'M GOING TO HAVE...                  NaN
# 576   @SkyWilliams doggo simply protecting you from ...                  NaN
# 611   @JODYHiGHROLLER it may be an 11/10 but what do...                  NaN
# 701             13/10 for breakdancing puppo @shibbnbot                  NaN
# 707      Today, 10/10, should be National Dog Rates Day                  NaN
# 843   His name is Charley and he already has a new s...                  NaN
# 857   @TheEllenShow I'm not sure if you know this bu...                  NaN
# 967                13/10 such a good doggo\n@spaghemily                  NaN
# 1005  Other pupper asked not to have his identity sh...                  NaN
# 1080                                 @mount_alex3 13/10                  NaN
# 1295  @serial @MrRoles OH MY GOD I listened to all o...                  NaN
# 1345                                13/10 hero af\n@ABC                  NaN
# 1445    Oh my god 10/10 for every little hot dog pupper                  NaN
# 1446  After reading the comments I may have overesti...                  NaN
# 1474  BREAKING PUPDATE: I've just been notified that...                  NaN
# 1479  Personally I'd give him an 11/10. Not sure why...                  NaN
# 1497  PUPDATE: just noticed this dog has some extra ...                  NaN
# 1523                              12/10 @LightningHoltt                  NaN
# 1598  Yes I do realize a rating of 4/20 would've bee...                  NaN
# 1605  Jack deserves another round of applause. If yo...                  NaN
# 1618  For those who claim this is a goat, u are wron...                  NaN
# 1663  I'm aware that I could've said 20/16, but here...                  NaN
# 1689  I've been told there's a slight possibility he...                  NaN
# 1774  After getting lost in Reese's eyes for several...                  NaN
# 1819  After some outrage from the crowd. Bubbles is ...                  NaN
# 1844  This dog is being demoted to a 9/10 for not we...                  NaN
# 1895  Some clarification is required. The dog is sin...                  NaN
# 1905  The 13/10 also takes into account this impecca...                  NaN
# 1914                                       13/10\n@ABC7                  NaN
# 1940  The millennials have spoken and we've decided ...                  NaN
# 2038  After 22 minutes of careful deliberation this ...                  NaN
# 2149  After countless hours of research and hundreds...                  NaN
# 2189                     12/10 good shit Bubka\n@wane15                  NaN
# 2298  After much debate this dog is being upgraded t...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp expanded_urls  \
# 30                         NaN                        NaN           NaN
# 55                         NaN                        NaN           NaN
# 64                         NaN                        NaN           NaN
# 113                        NaN                        NaN           NaN
# 148                        NaN                        NaN           NaN
# 179                        NaN                        NaN           NaN
# 185                 66699013.0  2017-04-24 02:13:14 +0000           NaN
# 186                        NaN                        NaN           NaN
# 188                        NaN                        NaN           NaN
# 189                        NaN                        NaN           NaN
# 218                        NaN                        NaN           NaN
# 228                        NaN                        NaN           NaN
# 234                        NaN                        NaN           NaN
# 274                        NaN                        NaN           NaN
# 290                        NaN                        NaN           NaN
# 291                        NaN                        NaN           NaN
# 313                        NaN                        NaN           NaN
# 342                        NaN                        NaN           NaN
# 346                        NaN                        NaN           NaN
# 375                        NaN                        NaN           NaN
# 387                        NaN                        NaN           NaN
# 409                        NaN                        NaN           NaN
# 427                        NaN                        NaN           NaN
# 498                        NaN                        NaN           NaN
# 513                        NaN                        NaN           NaN
# 570                        NaN                        NaN           NaN
# 576                        NaN                        NaN           NaN
# 611                        NaN                        NaN           NaN
# 701                        NaN                        NaN           NaN
# 707                        NaN                        NaN           NaN
# 843                        NaN                        NaN           NaN
# 857                        NaN                        NaN           NaN
# 967                        NaN                        NaN           NaN
# 1005                       NaN                        NaN           NaN
# 1080                       NaN                        NaN           NaN
# 1295                       NaN                        NaN           NaN
# 1345                       NaN                        NaN           NaN
# 1445                       NaN                        NaN           NaN
# 1446                       NaN                        NaN           NaN
# 1474                       NaN                        NaN           NaN
# 1479                       NaN                        NaN           NaN
# 1497                       NaN                        NaN           NaN
# 1523                       NaN                        NaN           NaN
# 1598                       NaN                        NaN           NaN
# 1605                       NaN                        NaN           NaN
# 1618                       NaN                        NaN           NaN
# 1663                       NaN                        NaN           NaN
# 1689                       NaN                        NaN           NaN
# 1774                       NaN                        NaN           NaN
# 1819                       NaN                        NaN           NaN
# 1844                       NaN                        NaN           NaN
# 1895                       NaN                        NaN           NaN
# 1905                       NaN                        NaN           NaN
# 1914                       NaN                        NaN           NaN
# 1940                       NaN                        NaN           NaN
# 2038                       NaN                        NaN           NaN
# 2149                       NaN                        NaN           NaN
# 2189                       NaN                        NaN           NaN
# 2298                       NaN                        NaN           NaN
#
#       rating_numerator  rating_denominator  name  doggo floofer  pupper  puppo
# 30                  12                  10  None   None    None    None   None
# 55                  17                  10  None   None    None    None   None
# 64                  14                  10  None   None    None    None   None
# 113                 10                  10  None   None    None    None   None
# 148                 12                  10  None   None    None    None   None
# 179                 12                  10  None   None    None    None   None
# 185                 14                  10  None   None    None    None   None
# 186                 14                  10  None   None    None    None   None
# 188                420                  10  None   None    None    None   None
# 189                666                  10  None   None    None    None   None
# 218                 13                  10  None   None    None    None   None
# 228                 11                  10  None   None    None    None   None
# 234                 13                  10  None   None    None    None   None
# 274                 10                  10  None   None    None    None   None
# 290                182                  10  None   None    None    None   None
# 291                 15                  10  None   None    None    None   None
# 313                960                   0  None   None    None    None   None
# 342                 11                  15  None   None    None    None   None
# 346                 12                  10  None   None    None    None   None
# 375                 12                  10  None   None    None    None   None
# 387                  7                  10  None   None    None    None   None
# 409                 13                  10  None   None    None    None   None
# 427                 13                  10  None   None    None    None   None
# 498                 12                  10  None   None    None    None   None
# 513                 11                  10  None   None    None    None   None
# 570                 11                  10  None   None    None    None   None
# 576                 11                  10  None  doggo    None    None   None
# 611                 11                  10  None   None    None    None   None
# 701                 13                  10  None   None    None    None  puppo
# 707                 10                  10  None   None    None    None   None
# 843                 13                  10  None   None    None    None   None
# 857                 12                  10  None  doggo    None    None   None
# 967                 13                  10  None  doggo    None    None   None
# 1005                12                  10  None   None    None  pupper   None
# 1080                13                  10  None   None    None    None   None
# 1295                12                  10  None   None    None    None   None
# 1345                13                  10  None   None    None    None   None
# 1445                10                  10  None   None    None  pupper   None
# 1446                 1                  10  None   None    None    None   None
# 1474                10                  10  None   None    None    None   None
# 1479                11                  10  None   None    None    None   None
# 1497                 9                  10  None   None    None    None   None
# 1523                12                  10  None   None    None    None   None
# 1598                 4                  20  None   None    None    None   None
# 1605                14                  10  None   None    None    None   None
# 1618                 5                  10  None   None    None    None   None
# 1663                20                  16  None   None    None    None   None
# 1689                 5                  10  None   None    None    None   None
# 1774                13                  10  None   None    None    None   None
# 1819                 7                  10  None   None    None    None   None
# 1844                 9                  10  None   None    None    None   None
# 1895                11                  10  None   None    None    None   None
# 1905                13                  10  None   None    None    None   None
# 1914                13                  10  None   None    None    None   None
# 1940                 1                  10  None   None    None    None   None
# 2038                 1                  10  None   None    None    None   None
# 2149                11                  10  None   None    None    None   None
# 2189                12                  10  None   None    None    None   None
# 2298                10                  10  None   None    None    None   None

# %%
weratedogs_twitter_archive_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# puppo                         2356 non-null object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %% [markdown]
# Below is an assessment of the data stored in the **weratedogs_twitter_archive_data** dataframe.

# %% [markdown]
# **Quallity**

# %% [markdown]
# - "timestamp" column in werate_dogs_twitter_data is of type str. Converting this to object timestamp can be useful for us while analyzing the data.
#
# - Missing values in columns in_reply_to_user_id, in_reply_to_status_id, retweeted_user_id, retweeted_status_timestamp. Are these columns very critical if we aren't really taking the retweet direction?
#
# - retweeted_status_id is of "np.float64" datatype. Convert to int64.
#
# - Missing "expanded_urls" values. What do we do with these rows? We can impute these rows.
#
# - dog names Null values: 'name' column contains values such as "None". It appears that the parsing of the names haven't been successful. We can treat these as missing values.
# - dog names unclean values: There are values in the 'name' column such as "a", "getting", "actually", etc.. These are not real dog names. These appear to be errors from trying to parse out the names of dogs.
# - Some "tweet_id" values result in missing/non-existing tweets and are in some cases wrong tweet IDs. For example: in index #21, Tweet ID: 888202515573088257 doesnt exist. We can however attempt to get the details of this tweet from the expanded_url column.
#
# - There are some unclean data with the Rating Numerators and denominators. There is one tweet with a rating of 9/10 but the numerator and denominator columns are 24,7 respectively and 1 tweet with a denominator value equals to 0. These appear to be parsing errors.<br>
#
# - There are some values of rating denominators in the dataset that are as high as 170. The corresponding rating numerator for this dog is 204. This clearly indicates that the dog is rated at 12/10 or a 120 on a percentage score basis. Standardinzing will help us with analysis.<br>
#
# - Outlier Values in rating numerators: Some dogs are rated very highly or probably there is a clear bias or is done as a joke, such as the one that is rated at 420/10 or 1776/10. <br>

# %% [markdown]
# **Tidiness**
#
# - After standardization, Column "rating_denominator" becomes redundant. We can drop this column and convert rating_numerator to a standardized rating column.
# -  Columns doggo, floofer, pupper, puppo are values and not variable names; this violates the 3rd rule of Tidy data. Each observational unit does not form a table.
# - Column "source" in the WeRateDogsTwitter Archive data contains two variables, the website reference of the source and the description of the source as a HTML tag.
# - Column 'expanded_urls' contains multiple URLs, some of which are repetitions of the same photo URLs.

# %% [markdown]
# ## Clean

# %% [markdown]
# Data WeRateDogs Twitter Archive: **weratedogs_twitter_archive**

# %% [markdown]
# **Quality Issues**
#
# **Define**:
#
# - Convert "timestamp" column to datetime object using pandas to_datetime method.
#
# - Delete columns retweeted_status_user_id, retweeted_status_timestamp from the dataframe.
#
# - Convert retweeted_status_id from "np.float64" datatype to int64. Fill null values in these columns   with value -1.
#
# - Impute rows where 'expanded_urls' have null values.
#
# - replace bad data for dog name with data from the tweet text. The value to search for and the value to replace with are found in file missing_dog_names.csv.
#
# - Some "tweet_id" values result in missing/non-existing tweets and are in some cases wrong tweet IDs. For such tweet IDs replace tweet_id with the tweet_id found in the expanded_url column. I will try to achieve this when I query the twitter API below. These values will be retrieved later while querying the twitter API under section "Gathering Data - Getting data from twitter API".
#
# - We aren't really using retweet data. These columns will be removed from the dataset after queries to Twitter API are done. I am postponing this to the end of my data cleaning.

# %% [markdown]
# **Code**

# %%
from datetime import datetime

# %%
weratedogs_twitter_archive_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# puppo                         2356 non-null object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %%
weratedogs_copy = weratedogs_twitter_archive_data.copy()
weratedogs_copy['retweeted_status_id'] = weratedogs_copy['retweeted_status_id'].fillna(-1).astype(np.int64)
weratedogs_copy = weratedogs_copy.drop(["retweeted_status_user_id","retweeted_status_timestamp"], axis=1)
weratedogs_copy["timestamp"] = pd.to_datetime(weratedogs_copy["timestamp"], errors='coerce')
weratedogs_copy =  weratedogs_copy[~weratedogs_copy['expanded_urls'].isnull()]

# %%
# Cleans and fills in dog names.
clean_dog_names = pd.read_csv("missing_dog_names.csv")
clean_dog_names.head()
# Out:
#    index_num search replace_with
# 0        649      a      Forrest
# 1       1955      a          Kip
# 2       2034      a        Jacob
# 3       2066      a        Rufus
# 4       2116      a        Spork

# %%
for index, row in clean_dog_names.iterrows():
    ind_num = row['index_num']
    weratedogs_copy.loc[ind_num,"name"] = row['replace_with']

# %%
weratedogs_copy.loc[weratedogs_copy.name == "a","name"] = "None"

# %% [markdown]
# **Test**

# %%
weratedogs_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2297 entries, 0 to 2355
# Data columns (total 15 columns):
# tweet_id                 2297 non-null int64
# in_reply_to_status_id    23 non-null float64
# in_reply_to_user_id      23 non-null float64
# timestamp                2297 non-null datetime64[ns]
# source                   2297 non-null object
# text                     2297 non-null object
# retweeted_status_id      2297 non-null int64
# expanded_urls            2297 non-null object
# rating_numerator         2297 non-null int64
# rating_denominator       2297 non-null int64
# name                     2297 non-null object
# doggo                    2297 non-null object
# floofer                  2297 non-null object
# pupper                   2297 non-null object
# puppo                    2297 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(4), object(8)
# memory usage: 367.1+ KB

# %%
weratedogs_copy.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#             timestamp                                             source  \
# 0 2017-08-01 16:23:56  <a href="http://twitter.com/download/iphone" r...
# 1 2017-08-01 00:17:27  <a href="http://twitter.com/download/iphone" r...
# 2 2017-07-31 00:18:03  <a href="http://twitter.com/download/iphone" r...
# 3 2017-07-30 15:58:51  <a href="http://twitter.com/download/iphone" r...
# 4 2017-07-29 16:00:24  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                   -1
# 1  This is Tilly. She's just checking pup on you....                   -1
# 2  This is Archie. He is a rare Norwegian Pouncin...                   -1
# 3  This is Darla. She commenced a snooze mid meal...                   -1
# 4  This is Franklin. He would like you to stop ca...                   -1
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name doggo floofer pupper puppo
# 0                  10   Phineas  None    None   None  None
# 1                  10     Tilly  None    None   None  None
# 2                  10    Archie  None    None   None  None
# 3                  10     Darla  None    None   None  None
# 4                  10  Franklin  None    None   None  None

# %%
weratedogs_copy.loc[[649,1955],"name"]
# Out:
# 649      Forrest
# 1955         Kip
# Name: name, dtype: object

# %% [markdown]
# #### Cleaning and Standardizing Dog ratings

# %% [markdown]
# The WeRateDogs Twitter Archive data contains observations where the rating values are not parsed properly. As an example, lets look at TweetID: 666287406224695296. The tweet text for this tweet gives a rating of 9/10, but however a rating of 1/2 is parsed wrongly.
#
# For this, we can clean-up these rating values programattically by setting up a search-and-replace dictionary __ratings_search_replace__, that would replace the existing incorrect pair of rating numerator and rating denominator with the actual numerator and denominator.

# %%
# A search and replace dictionary is used to replace with the correct ratings values.
ratings_search_replace = [{"rating_values_existing":(1,2), "rating_values_replace":(9,10)},
                          {"rating_values_existing":(960,0), "rating_values_replace":(13,10)},
                          {"rating_values_existing":(7,11), "rating_values_replace":(10,10)},
                          {"rating_values_existing":(960,0), "rating_values_replace":(13,10)},
                          {"rating_values_existing":(9,11), "rating_values_replace":(14,10)}]

for item in ratings_search_replace: 

    condition = (weratedogs_copy.rating_denominator == item["rating_values_existing"][1]) & (weratedogs_copy.rating_numerator == item["rating_values_existing"][0])
    weratedogs_copy.loc[condition,"rating_denominator"] = item["rating_values_replace"][1]
    weratedogs_copy.loc[condition,"rating_numerator"] = item["rating_values_replace"][0]

# %% [markdown]
# Here we Test if the values are correct:

# %%
assert ((weratedogs_copy.rating_denominator == ratings_search_replace[0]["rating_values_existing"][1]) & (weratedogs_copy.rating_numerator == ratings_search_replace[0]["rating_values_existing"][0])).sum() == 0
assert ((weratedogs_copy.rating_denominator == ratings_search_replace[1]["rating_values_existing"][1]) & (weratedogs_copy.rating_numerator == ratings_search_replace[1]["rating_values_existing"][0])).sum() == 0
assert ((weratedogs_copy.rating_denominator == ratings_search_replace[2]["rating_values_existing"][1]) & (weratedogs_copy.rating_numerator == ratings_search_replace[2]["rating_values_existing"][0])).sum() == 0

# %% [markdown]
# Now that our values have been made correct, we make sure that our rating is standardized, such that a rating of 120/100 is same as 12/10. Although, WeRateDogs may not like this standardization to make the denominator equals to 10, it helps with our analysis though, without losing much information.
#
# So Now, we set the numerator proportional to denominator multiplied by 10.

# %%
weratedogs_copy.loc[weratedogs_copy.rating_denominator > 10,"rating_numerator"] = 10*(weratedogs_copy.loc[weratedogs_copy.rating_denominator > 10,"rating_numerator"])/(weratedogs_copy.loc[weratedogs_copy.rating_denominator > 10, "rating_denominator"])
weratedogs_copy.loc[weratedogs_copy.rating_denominator > 10,"rating_denominator"] = 10

# %% [markdown]
# #### Test

# %%
weratedogs_copy.rating_denominator.unique()
weratedogs_copy.rating_numerator = weratedogs_copy.rating_numerator.astype(np.int64)
weratedogs_copy.rating_numerator.unique()
# Out:
# array([  13,   12,   14,    5,   11,   10,    6,   15,    0,   75,    7,
#           9,   24,    8,    1,   27,    3,    4, 1776,    2,   26,  420],
#       dtype=int64)

# %% [markdown]
# We still do find that there are some very large values in the ratings numerator column. I am going to drop these, since these would potentially be outliers for our analysis.

# %%
values_to_remove = [75,420,666,1776,182]
weratedogs_copy = weratedogs_copy[~weratedogs_copy.rating_numerator.isin(values_to_remove)]

# %%
weratedogs_twitter_archive_data = weratedogs_copy

# %% [markdown]
# **Tidiness Issues**:
#
# **Define**
#
#
# **1.** Drop column "rating_denominator" and rename "rating_numerator" to "standardized_rating".
#
#
# **2.**
# "source" column violates the principle of tidy data. __Each variable forms a column.__. There are 2 variables contained in the "source" variable. Use regular expressions to filter for the URL and the source description from each row.
#
#
# **3.**
# Columns doggo, floofer, pupper, puppo are variable values and not variable names. These column names are values to a dog stage. A value of True in Column doggo indicates that this particular dog is in the "doggo" stage.
# More about dog lingo here: https://www.rover.com/blog/everything-you-need-to-know-about-doggo-lingo/
# Create a new column "dog stage" that outputs the 'non-None' value in these 4 columns to one value. Remove columns 'doggo', 'floofer', 'pupper', 'puppo'.
#
# **4.**
# I am going to postpone clearing the tidiness issue for expanded_urls. This will be done once the data from Twitter API is retrieved.

# %% [markdown]
# **Code**

# %%
weratedogs_copy = weratedogs_twitter_archive_data.copy()

# %% [markdown]
# Drop the Rating Denominator column.

# %%
weratedogs_copy = weratedogs_copy.drop("rating_denominator",axis=1)
weratedogs_copy = weratedogs_copy.rename(index=str, columns= {"rating_numerator":"standardized_rating"})

# %%
weratedogs_copy.columns.values
# Out:
# array(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id',
#        'timestamp', 'source', 'text', 'retweeted_status_id',
#        'expanded_urls', 'standardized_rating', 'name', 'doggo', 'floofer',
#        'pupper', 'puppo'], dtype=object)

# %%
weratedogs_copy["source_description"] = pd.Series([(re.findall('\>([^\<]*)\<\/a\>',x)[0]).rstrip() for x in weratedogs_copy["source"].values], index=weratedogs_copy.index)
weratedogs_copy["source_urls"] = pd.Series([(re.findall('\<a href=\"([^\"]*)\"',x)[0]).rstrip() for x in weratedogs_copy["source"].values] , index=weratedogs_copy.index)

# %%
weratedogs_copy = weratedogs_copy.drop(columns=['source'])

# %%
weratedogs_copy.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'text', 'retweeted_status_id', 'expanded_urls', 'standardized_rating',
#        'name', 'doggo', 'floofer', 'pupper', 'puppo', 'source_description',
#        'source_urls'],
#       dtype='object')

# %%
weratedogs_copy = weratedogs_copy[['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
                                   'source_urls', 'source_description','text', 'retweeted_status_id', 'expanded_urls', 'standardized_rating',
                                   'name', 'doggo', 'floofer', 'pupper', 'puppo',
                                   ]]

# %%
weratedogs_copy.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#             timestamp                         source_urls  source_description  \
# 0 2017-08-01 16:23:56  http://twitter.com/download/iphone  Twitter for iPhone
# 1 2017-08-01 00:17:27  http://twitter.com/download/iphone  Twitter for iPhone
# 2 2017-07-31 00:18:03  http://twitter.com/download/iphone  Twitter for iPhone
# 3 2017-07-30 15:58:51  http://twitter.com/download/iphone  Twitter for iPhone
# 4 2017-07-29 16:00:24  http://twitter.com/download/iphone  Twitter for iPhone
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                   -1
# 1  This is Tilly. She's just checking pup on you....                   -1
# 2  This is Archie. He is a rare Norwegian Pouncin...                   -1
# 3  This is Darla. She commenced a snooze mid meal...                   -1
# 4  This is Franklin. He would like you to stop ca...                   -1
#
#                                        expanded_urls  standardized_rating  \
# 0  https://twitter.com/dog_rates/status/892420643...                   13
# 1  https://twitter.com/dog_rates/status/892177421...                   13
# 2  https://twitter.com/dog_rates/status/891815181...                   12
# 3  https://twitter.com/dog_rates/status/891689557...                   13
# 4  https://twitter.com/dog_rates/status/891327558...                   12
#
#        name doggo floofer pupper puppo
# 0   Phineas  None    None   None  None
# 1     Tilly  None    None   None  None
# 2    Archie  None    None   None  None
# 3     Darla  None    None   None  None
# 4  Franklin  None    None   None  None

# %% [markdown]
# We find that columns "doggo", "floofer", etc.. contain values "None" (as in string not Type), which indicates an absence of value. Also there are 14 rows in the dataset that have multiple dog life stages.

# %%
dog_stages = weratedogs_copy[["doggo","floofer","pupper","puppo"]]
((dog_stages != "None").sum(axis=1)).value_counts()
# Out:
# 0    1919
# 1     360
# 2      14
# dtype: int64

# %%
dog_stages["doggo"].replace("None","",inplace=True)
dog_stages["floofer"].replace("None","",inplace=True)
dog_stages["pupper"].replace("None","",inplace=True)
dog_stages["puppo"].replace("None","",inplace=True)
# Out:
# c:\python37\lib\site-packages\pandas\core\generic.py:5890: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
cols = ["doggo","floofer","pupper","puppo"]
dog_stage = []
for index, row in dog_stages.iterrows():
    stage_val = ""
    for k in cols:
        if row[k]:
            stage_val = stage_val + "-" + row[k]
    stage_val = stage_val.strip('-')
    dog_stage.append(stage_val)

# %%
weratedogs_copy["dog_stage"] = pd.Series(dog_stage,index=weratedogs_copy.index)
weratedogs_copy.loc[weratedogs_copy["dog_stage"] == "","dog_stage"] = "None"
weratedogs_copy = weratedogs_copy.drop(columns = ["doggo","floofer","pupper","puppo"])
weratedogs_twitter_archive_data = weratedogs_copy
weratedogs_twitter_archive_data.columns

# %% [markdown]
# ## Gathering Data - Getting data from Twitter API

# %% [markdown]
# In this section, we grab twitter data from the Twitter API for each tweet ID listed in the weratedogs twitter Archive. There appears to be some tweet ID's from our original twitter archive csv file, for which the tweets have been deleted. Such tweets do not carry other info, such as # of Retweets, likes etc.. I have collected such tweets in file "unauthorized_tweet_ids.csv". For example, Tweet ID 680055455951884288 appears to be deleted.
#
# There also appear to be certain Tweet ID's that do not contain a valid ID, however, the retweet ID/the tweet ID found in the media URL is valid and turns out that these tweets are not really retweets and are tweeted by User @dog_rates.
# For example, tweet ID: 770743923962707968 doesnt exist. URL: https://twitter.com/dog_rates/status/770743923962707968 doesnt exist. However, the media URLs associated with this row in archive returns a valid tweet, which is at the website:
# https://twitter.com/dog_rates/status/739238157791694849/video/1 , where we see this dog blowing bubbles :)
# The below code collects the JSON object pertaining to the tweet ID found from the Media URL/ retweeted ID.

# %%
api = get_twitter_API()

# %%
output_json_obj = []

file_handle = open("unauthorized_tweet_ids.csv","w")

unauthorized_csv = csv.writer(file_handle, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL,lineterminator="\n")
headers = ["index","tweet_id","retweet_status_id","status_id_from_media_url"]
unauthorized_csv.writerow(headers)
count = 0

for index,row in weratedogs_twitter_archive_data.iterrows():
    
    print ("Fetching Tweet API data from row #: {}".format(int(index)+1))
    json_obj = get_json_data(api,row)
   
    if not json_obj:
        unauthorized_csv.writerow([int(index)+1, row["tweet_id"],row["retweeted_status_id"],get_tweet_id_from_urls(row["expanded_urls"])])
    
    output_json_obj.append(json_obj)

file_handle.close()
# Out:
# Fetching Tweet API data from row #: 1
# Fetching Tweet API data from row #: 2
# Fetching Tweet API data from row #: 3
# Fetching Tweet API data from row #: 4
# Fetching Tweet API data from row #: 5
# Fetching Tweet API data from row #: 6
# Fetching Tweet API data from row #: 7
# Fetching Tweet API data from row #: 8
# Fetching Tweet API data from row #: 9
# Fetching Tweet API data from row #: 10
# Fetching Tweet API data from row #: 11
# Fetching Tweet API data from row #: 12
# Fetching Tweet API data from row #: 13
# Fetching Tweet API data from row #: 14
# Fetching Tweet API data from row #: 15
# Fetching Tweet API data from row #: 16
# Fetching Tweet API data from row #: 17
# Fetching Tweet API data from row #: 18
# Fetching Tweet API data from row #: 19
# Fetching Tweet API data from row #: 20
# The Tweet ID: 888202515573088257 does not exist in the Twitter API
# Trying Retweet ID: 887473957103951872
# The Tweet ID: 887473957103951872 does not exist in the Twitter API
# Trying Tweet ID from the Media URL: 887473957103951883
# Fetching Tweet API data from row #: 21
# Fetching Tweet API data from row #: 22
# Fetching Tweet API data from row #: 23
# Fetching Tweet API data from row #: 24
# Fetching Tweet API data from row #: 25
# Fetching Tweet API data from row #: 26
# Fetching Tweet API data from row #: 27
# Fetching Tweet API data from row #: 28
# Fetching Tweet API data from row #: 29
# Fetching Tweet API data from row #: 30
# Fetching Tweet API data from row #: 32
# Fetching Tweet API data from row #: 33
# Fetching Tweet API data from row #: 34
# Fetching Tweet API data from row #: 35
# Fetching Tweet API data from row #: 36
# Fetching Tweet API data from row #: 37
# Fetching Tweet API data from row #: 38
# Fetching Tweet API data from row #: 39
# Fetching Tweet API data from row #: 40
# Fetching Tweet API data from row #: 41
# Fetching Tweet API data from row #: 42
# Fetching Tweet API data from row #: 43
# Fetching Tweet API data from row #: 44
# Fetching Tweet API data from row #: 45
# Fetching Tweet API data from row #: 46
# Fetching Tweet API data from row #: 47
# Fetching Tweet API data from row #: 48
# Fetching Tweet API data from row #: 49
# Fetching Tweet API data from row #: 50
# Fetching Tweet API data from row #: 51
# Fetching Tweet API data from row #: 52
# Fetching Tweet API data from row #: 53
# Fetching Tweet API data from row #: 54
# Fetching Tweet API data from row #: 55
# Fetching Tweet API data from row #: 57
# Fetching Tweet API data from row #: 58
# Fetching Tweet API data from row #: 59
# Fetching Tweet API data from row #: 60
# Fetching Tweet API data from row #: 61
# Fetching Tweet API data from row #: 62
# Fetching Tweet API data from row #: 63
# Fetching Tweet API data from row #: 64
# Fetching Tweet API data from row #: 66
# Fetching Tweet API data from row #: 67
# Fetching Tweet API data from row #: 68
# Fetching Tweet API data from row #: 69
# Fetching Tweet API data from row #: 70
# Fetching Tweet API data from row #: 71
# Fetching Tweet API data from row #: 72
# Fetching Tweet API data from row #: 73
# Fetching Tweet API data from row #: 74
# Fetching Tweet API data from row #: 75
# Fetching Tweet API data from row #: 76
# Fetching Tweet API data from row #: 77
# Fetching Tweet API data from row #: 78
# Fetching Tweet API data from row #: 79
# Fetching Tweet API data from row #: 80
# Fetching Tweet API data from row #: 81
# Fetching Tweet API data from row #: 82
# Fetching Tweet API data from row #: 83
# Fetching Tweet API data from row #: 84
# Fetching Tweet API data from row #: 85
# Fetching Tweet API data from row #: 86
# Fetching Tweet API data from row #: 87
# Fetching Tweet API data from row #: 88
# Fetching Tweet API data from row #: 89
# Fetching Tweet API data from row #: 90
# Fetching Tweet API data from row #: 91
# Fetching Tweet API data from row #: 92
# Fetching Tweet API data from row #: 93
# Fetching Tweet API data from row #: 94
# Fetching Tweet API data from row #: 95
# Fetching Tweet API data from row #: 96
# The Tweet ID: 873697596434513921 does not exist in the Twitter API
# Trying Retweet ID: 868880397819494400
# The Tweet ID: 868880397819494400 does not exist in the Twitter API
# Trying Tweet ID from the Media URL: 868880397819494401
# Fetching Tweet API data from row #: 97
# Fetching Tweet API data from row #: 98
# Fetching Tweet API data from row #: 99
# Fetching Tweet API data from row #: 100
# Fetching Tweet API data from row #: 101
# Fetching Tweet API data from row #: 102
# The Tweet ID: 872668790621863937 does not exist in the Twitter API
# Trying Retweet ID: 872657584259551232
# The Tweet ID: 872657584259551232 does not exist in the Twitter API
# Trying Tweet ID from the Media URL: 872657584259551233
# The Tweet ID: 872657584259551233 does not exist in the Twitter API
# Unable to fetch Tweet IDs
# Fetching Tweet API data from row #: 103
# Fetching Tweet API data from row #: 104
# Fetching Tweet API data from row #: 105
# The Tweet ID: 872261713294495745 does not exist in the Twitter API
# Trying Tweet ID from the Media URL: 872261713294495745
# The Tweet ID: 872261713294495745 does not exist in the Twitter API
# Unable to fetch Tweet IDs
# Fetching Tweet API data from row #: 106
# Fetching Tweet API data from row #: 107
# Fetching Tweet API data from row #: 108
# Fetching Tweet API data from row #: 109
# Fetching Tweet API data from row #: 110
# Fetching Tweet API data from row #: 111
# Fetching Tweet API data from row #: 112
# Fetching Tweet API data from row #: 113
# Fetching Tweet API data from row #: 115
# Fetching Tweet API data from row #: 116
# Fetching Tweet API data from row #: 117
# Fetching Tweet API data from row #: 118
# Fetching Tweet API data from row #: 119
# The Tweet ID: 869988702071779329 does not exist in the Twitter API
# Trying Retweet ID: 859196978902773760
# Fetching Tweet API data from row #: 120
# Fetching Tweet API data from row #: 121
# Fetching Tweet API data from row #: 122
# Fetching Tweet API data from row #: 123
# Fetching Tweet API data from row #: 124
# Fetching Tweet API data from row #: 125
# Fetching Tweet API data from row #: 126
# Fetching Tweet API data from row #: 127
# Fetching Tweet API data from row #: 128
# Fetching Tweet API data from row #: 129
# Fetching Tweet API data from row #: 130
# Fetching Tweet API data from row #: 131
# Fetching Tweet API data from row #: 132
# Fetching Tweet API data from row #: 133
# The Tweet ID: 866816280283807744 does not exist in the Twitter API
# Trying Retweet ID: 866450705531457536
# Fetching Tweet API data from row #: 134
# Fetching Tweet API data from row #: 135
# Fetching Tweet API data from row #: 136
# Fetching Tweet API data from row #: 137
# Fetching Tweet API data from row #: 138
# Fetching Tweet API data from row #: 139
# Fetching Tweet API data from row #: 140
# Fetching Tweet API data from row #: 141
# Fetching Tweet API data from row #: 142
# Fetching Tweet API data from row #: 143
# Fetching Tweet API data from row #: 144
# Fetching Tweet API data from row #: 145
# Fetching Tweet API data from row #: 146
# Fetching Tweet API data from row #: 147
# Fetching Tweet API data from row #: 148
# Fetching Tweet API data from row #: 150
# Fetching Tweet API data from row #: 151
# Fetching Tweet API data from row #: 152
# Fetching Tweet API data from row #: 153
# Fetching Tweet API data from row #: 154
# Fetching Tweet API data from row #: 155
# Fetching Tweet API data from row #: 156
# The Tweet ID: 861769973181624320 does not exist in the Twitter API
# Trying Retweet ID: 806629075125202944
# The Tweet ID: 806629075125202944 does not exist in the Twitter API
# Trying Tweet ID from the Media URL: 806629075125202948
# Fetching Tweet API data from row #: 157
# Fetching Tweet API data from row #: 158
# Fetching Tweet API data from row #: 159
# Fetching Tweet API data from row #: 160
# Fetching Tweet API data from row #: 161
# Fetching Tweet API data from row #: 162
# Fetching Tweet API data from row #: 163
# Fetching Tweet API data from row #: 164
# Fetching Tweet API data from row #: 165
# Fetching Tweet API data from row #: 166
# Fetching Tweet API data from row #: 167
# Fetching Tweet API data from row #: 168
# Fetching Tweet API data from row #: 169
# Fetching Tweet API data from row #: 170
# Fetching Tweet API data from row #: 171
# Fetching Tweet API data from row #: 172
# Fetching Tweet API data from row #: 173
# Fetching Tweet API data from row #: 174
# Fetching Tweet API data from row #: 175
# Fetching Tweet API data from row #: 176
# Fetching Tweet API data from row #: 177
# Fetching Tweet API data from row #: 178
# Fetching Tweet API data from row #: 179
# Fetching Tweet API data from row #: 181
# Fetching Tweet API data from row #: 182
# Fetching Tweet API data from row #: 183
# Fetching Tweet API data from row #: 184
# Fetching Tweet API data from row #: 185
# Fetching Tweet API data from row #: 188
# Fetching Tweet API data from row #: 191
# Fetching Tweet API data from row #: 192
# Fetching Tweet API data from row #: 193
# Fetching Tweet API data from row #: 194
# Fetching Tweet API data from row #: 195
# Fetching Tweet API data from row #: 196
# Fetching Tweet API data from row #: 197
# Fetching Tweet API data from row #: 198
# Fetching Tweet API data from row #: 199
# Fetching Tweet API data from row #: 200
# Fetching Tweet API data from row #: 201
# Fetching Tweet API data from row #: 202
# Fetching Tweet API data from row #: 203
# Fetching Tweet API data from row #: 204
# Fetching Tweet API data from row #: 205
# Fetching Tweet API data from row #: 206
# Fetching Tweet API data from row #: 207
# Fetching Tweet API data from row #: 208
# Fetching Tweet API data from row #: 209
# Fetching Tweet API data from row #: 210
# Fetching Tweet API data from row #: 211
# Fetching Tweet API data from row #: 212
# Fetching Tweet API data from row #: 213
# Fetching Tweet API data from row #: 214
# Fetching Tweet API data from row #: 215
# Fetching Tweet API data from row #: 216
# Fetching Tweet API data from row #: 217
# Fetching Tweet API data from row #: 218
# Fetching Tweet API data from row #: 220
# Fetching Tweet API data from row #: 221
# Fetching Tweet API data from row #: 222
# Fetching Tweet API data from row #: 223
# Fetching Tweet API data from row #: 224
# Fetching Tweet API data from row #: 225
# Fetching Tweet API data from row #: 226
# Fetching Tweet API data from row #: 227
# Fetching Tweet API data from row #: 228
# Fetching Tweet API data from row #: 230
# Fetching Tweet API data from row #: 231
# Fetching Tweet API data from row #: 232
# Fetching Tweet API data from row #: 233
# Fetching Tweet API data from row #: 234
# Fetching Tweet API data from row #: 236
# Fetching Tweet API data from row #: 237
# Fetching Tweet API data from row #: 238
# Fetching Tweet API data from row #: 239
# Fetching Tweet API data from row #: 240
# Fetching Tweet API data from row #: 241
# Fetching Tweet API data from row #: 242
# Fetching Tweet API data from row #: 243
# Fetching Tweet API data from row #: 244
# Fetching Tweet API data from row #: 245
# Fetching Tweet API data from row #: 246
# Fetching Tweet API data from row #: 247
# Fetching Tweet API data from row #: 248
# The Tweet ID: 845459076796616705 does not exist in the Twitter API
# Trying Retweet ID: 756288534030475264
# Fetching Tweet API data from row #: 249
# Fetching Tweet API data from row #: 250
# Fetching Tweet API data from row #: 251
# Fetching Tweet API data from row #: 252
# Fetching Tweet API data from row #: 253
# Fetching Tweet API data from row #: 254
# Fetching Tweet API data from row #: 255
# Fetching Tweet API data from row #: 256
# Fetching Tweet API data from row #: 257
# Fetching Tweet API data from row #: 258
# Fetching Tweet API data from row #: 259
# Fetching Tweet API data from row #: 260
# Fetching Tweet API data from row #: 261
# The Tweet ID: 842892208864923648 does not exist in the Twitter API
# Trying Retweet ID: 807106840509214720
# Fetching Tweet API data from row #: 262
# Fetching Tweet API data from row #: 263
# Fetching Tweet API data from row #: 264
# Fetching Tweet API data from row #: 265
# Fetching Tweet API data from row #: 266
# Fetching Tweet API data from row #: 267
# Fetching Tweet API data from row #: 268
# Fetching Tweet API data from row #: 269
# Fetching Tweet API data from row #: 270
# Fetching Tweet API data from row #: 271
# Fetching Tweet API data from row #: 272
# Fetching Tweet API data from row #: 273
# Fetching Tweet API data from row #: 274
# Fetching Tweet API data from row #: 276
# Fetching Tweet API data from row #: 277
# Fetching Tweet API data from row #: 278
# Fetching Tweet API data from row #: 279
# Fetching Tweet API data from row #: 280
# Fetching Tweet API data from row #: 281
# Fetching Tweet API data from row #: 282
# Fetching Tweet API data from row #: 283
# Fetching Tweet API data from row #: 284
# Fetching Tweet API data from row #: 285
# Fetching Tweet API data from row #: 286
# Fetching Tweet API data from row #: 287
# Fetching Tweet API data from row #: 288
# Fetching Tweet API data from row #: 289
# Fetching Tweet API data from row #: 290
# Fetching Tweet API data from row #: 293
# Fetching Tweet API data from row #: 294
# Fetching Tweet API data from row #: 295
# Fetching Tweet API data from row #: 296
# Fetching Tweet API data from row #: 297
# Fetching Tweet API data from row #: 298
# Fetching Tweet API data from row #: 299
# The Tweet ID: 837012587749474308 does not exist in the Twitter API
# Trying Retweet ID: 837011344666812416
# The Tweet ID: 837011344666812416 does not exist in the Twitter API
# Trying Tweet ID from the Media URL: 837011344666812416
# The Tweet ID: 837011344666812416 does not exist in the Twitter API
# Unable to fetch Tweet IDs
# Fetching Tweet API data from row #: 300
# Fetching Tweet API data from row #: 301
# Fetching Tweet API data from row #: 302
# Fetching Tweet API data from row #: 303
# Fetching Tweet API data from row #: 304
# Fetching Tweet API data from row #: 305
# Fetching Tweet API data from row #: 306
# Fetching Tweet API data from row #: 307
# Fetching Tweet API data from row #: 308
# Fetching Tweet API data from row #: 309
# Fetching Tweet API data from row #: 310
# Fetching Tweet API data from row #: 311
# Fetching Tweet API data from row #: 312
# Fetching Tweet API data from row #: 313
# Fetching Tweet API data from row #: 315
# Fetching Tweet API data from row #: 316
# Fetching Tweet API data from row #: 317
# Fetching Tweet API data from row #: 318
# Fetching Tweet API data from row #: 319
# Fetching Tweet API data from row #: 320
# Fetching Tweet API data from row #: 321
# Fetching Tweet API data from row #: 322
# Fetching Tweet API data from row #: 323
# Fetching Tweet API data from row #: 324
# Fetching Tweet API data from row #: 325
# Fetching Tweet API data from row #: 326
# Fetching Tweet API data from row #: 327
# Fetching Tweet API data from row #: 328
# Fetching Tweet API data from row #: 329
# Fetching Tweet API data from row #: 330
# Fetching Tweet API data from row #: 331
# Fetching Tweet API data from row #: 332
# Fetching Tweet API data from row #: 333
# Fetching Tweet API data from row #: 334
# Fetching Tweet API data from row #: 335
# Fetching Tweet API data from row #: 336
# Fetching Tweet API data from row #: 337
# Fetching Tweet API data from row #: 338
# Fetching Tweet API data from row #: 339
# Fetching Tweet API data from row #: 340
# Fetching Tweet API data from row #: 342
# Fetching Tweet API data from row #: 344
# Fetching Tweet API data from row #: 345
# Fetching Tweet API data from row #: 346
# Fetching Tweet API data from row #: 348
# Fetching Tweet API data from row #: 349
# Fetching Tweet API data from row #: 350
# Fetching Tweet API data from row #: 351
# Fetching Tweet API data from row #: 352
# Fetching Tweet API data from row #: 353
# Fetching Tweet API data from row #: 354
# Fetching Tweet API data from row #: 355
# Fetching Tweet API data from row #: 356
# Fetching Tweet API data from row #: 357
# Fetching Tweet API data from row #: 358
# Fetching Tweet API data from row #: 359
# Fetching Tweet API data from row #: 360
# Fetching Tweet API data from row #: 361
# Fetching Tweet API data from row #: 362
# Fetching Tweet API data from row #: 363
# Fetching Tweet API data from row #: 364
# Fetching Tweet API data from row #: 365
# Fetching Tweet API data from row #: 366
# Fetching Tweet API data from row #: 367
# Fetching Tweet API data from row #: 368
# Fetching Tweet API data from row #: 369
# Fetching Tweet API data from row #: 370
# Fetching Tweet API data from row #: 371
# Fetching Tweet API data from row #: 372
# Fetching Tweet API data from row #: 373
# Fetching Tweet API data from row #: 374
# Fetching Tweet API data from row #: 375
# Fetching Tweet API data from row #: 377
# Fetching Tweet API data from row #: 378
# Fetching Tweet API data from row #: 379
# Fetching Tweet API data from row #: 380
# Fetching Tweet API data from row #: 381
# Fetching Tweet API data from row #: 382
# Fetching Tweet API data from row #: 383
# The Tweet ID: 827228250799742977 does not exist in the Twitter API
# Trying Retweet ID: 694669722378485760
# Fetching Tweet API data from row #: 384
# Fetching Tweet API data from row #: 385
# Fetching Tweet API data from row #: 386
# Fetching Tweet API data from row #: 387
# Fetching Tweet API data from row #: 389
# Fetching Tweet API data from row #: 390
# Fetching Tweet API data from row #: 391
# Fetching Tweet API data from row #: 392
# Fetching Tweet API data from row #: 393
# Fetching Tweet API data from row #: 394
# Fetching Tweet API data from row #: 395
# Fetching Tweet API data from row #: 396
# Fetching Tweet API data from row #: 397
# Fetching Tweet API data from row #: 398
# Fetching Tweet API data from row #: 399
# Fetching Tweet API data from row #: 400
# Fetching Tweet API data from row #: 401
# Fetching Tweet API data from row #: 402
# Fetching Tweet API data from row #: 403
# Fetching Tweet API data from row #: 404
# Fetching Tweet API data from row #: 405
# Fetching Tweet API data from row #: 406
# Fetching Tweet API data from row #: 407
# Fetching Tweet API data from row #: 408
# Fetching Tweet API data from row #: 409
# Fetching Tweet API data from row #: 411
# Fetching Tweet API data from row #: 412
# Fetching Tweet API data from row #: 413
# Fetching Tweet API data from row #: 414
# Fetching Tweet API data from row #: 415
# Fetching Tweet API data from row #: 416
# Fetching Tweet API data from row #: 417
# Fetching Tweet API data from row #: 418
# Fetching Tweet API data from row #: 419
# Fetching Tweet API data from row #: 420
# Fetching Tweet API data from row #: 421
# Fetching Tweet API data from row #: 422
# Fetching Tweet API data from row #: 423
# Fetching Tweet API data from row #: 424
# Fetching Tweet API data from row #: 425
# Fetching Tweet API data from row #: 426
# Fetching Tweet API data from row #: 427
# Fetching Tweet API data from row #: 429
# Fetching Tweet API data from row #: 430
# Fetching Tweet API data from row #: 431
# Fetching Tweet API data from row #: 432
# Fetching Tweet API data from row #: 433
# Fetching Tweet API data from row #: 434
# Fetching Tweet API data from row #: 435
# Fetching Tweet API data from row #: 436
# Fetching Tweet API data from row #: 437
# Fetching Tweet API data from row #: 438
# Fetching Tweet API data from row #: 439
# Fetching Tweet API data from row #: 440
# Fetching Tweet API data from row #: 441
# Fetching Tweet API data from row #: 442
# Fetching Tweet API data from row #: 443
# Fetching Tweet API data from row #: 444
# Fetching Tweet API data from row #: 445
# Fetching Tweet API data from row #: 446
# Fetching Tweet API data from row #: 447
# Fetching Tweet API data from row #: 448
# Fetching Tweet API data from row #: 449
# Fetching Tweet API data from row #: 450
# Fetching Tweet API data from row #: 451
# Fetching Tweet API data from row #: 452
# Fetching Tweet API data from row #: 453
# Fetching Tweet API data from row #: 454
# Fetching Tweet API data from row #: 455
# Fetching Tweet API data from row #: 456
# Fetching Tweet API data from row #: 457
# Fetching Tweet API data from row #: 458
# Fetching Tweet API data from row #: 459
# Fetching Tweet API data from row #: 460
# Fetching Tweet API data from row #: 461
# Fetching Tweet API data from row #: 462
# Fetching Tweet API data from row #: 463
# Fetching Tweet API data from row #: 464
# Fetching Tweet API data from row #: 465
# Fetching Tweet API data from row #: 466
# Fetching Tweet API data from row #: 467
# Fetching Tweet API data from row #: 468
# Fetching Tweet API data from row #: 469
# Fetching Tweet API data from row #: 470
# Fetching Tweet API data from row #: 471
# Fetching Tweet API data from row #: 472
# Fetching Tweet API data from row #: 473
# Fetching Tweet API data from row #: 474
# Fetching Tweet API data from row #: 475
# Fetching Tweet API data from row #: 476
# Fetching Tweet API data from row #: 477
# Fetching Tweet API data from row #: 478
# Fetching Tweet API data from row #: 479
# Fetching Tweet API data from row #: 480
# Fetching Tweet API data from row #: 481
# Fetching Tweet API data from row #: 482
# Fetching Tweet API data from row #: 483
# Fetching Tweet API data from row #: 484
# Fetching Tweet API data from row #: 485
# Fetching Tweet API data from row #: 486
# Fetching Tweet API data from row #: 487
# Fetching Tweet API data from row #: 488
# Fetching Tweet API data from row #: 489
# Fetching Tweet API data from row #: 490
# Fetching Tweet API data from row #: 491
# Fetching Tweet API data from row #: 492
# Fetching Tweet API data from row #: 493
# Fetching Tweet API data from row #: 494
# Fetching Tweet API data from row #: 495
# Fetching Tweet API data from row #: 496
# Fetching Tweet API data from row #: 497
# Fetching Tweet API data from row #: 498
# Fetching Tweet API data from row #: 500
# Fetching Tweet API data from row #: 501
# Fetching Tweet API data from row #: 502
# Fetching Tweet API data from row #: 503
# Fetching Tweet API data from row #: 504
# Fetching Tweet API data from row #: 505
# Fetching Tweet API data from row #: 506
# Fetching Tweet API data from row #: 507
# The Tweet ID: 812747805718642688 does not exist in the Twitter API
# Trying Retweet ID: 680055455951884288
# The Tweet ID: 680055455951884288 does not exist in the Twitter API
# Trying Tweet ID from the Media URL: 680055455951884288
# The Tweet ID: 680055455951884288 does not exist in the Twitter API
# Unable to fetch Tweet IDs
# Fetching Tweet API data from row #: 508
# Fetching Tweet API data from row #: 509
# Fetching Tweet API data from row #: 510
# Fetching Tweet API data from row #: 511
# Fetching Tweet API data from row #: 512
# Fetching Tweet API data from row #: 513
# Fetching Tweet API data from row #: 515
# Fetching Tweet API data from row #: 516
# Fetching Tweet API data from row #: 517
# Fetching Tweet API data from row #: 518
# Fetching Tweet API data from row #: 519
# Fetching Tweet API data from row #: 520
# Fetching Tweet API data from row #: 521
# Fetching Tweet API data from row #: 522
# Fetching Tweet API data from row #: 523
# Fetching Tweet API data from row #: 524
# Fetching Tweet API data from row #: 525
# Fetching Tweet API data from row #: 526
# Fetching Tweet API data from row #: 527
# Fetching Tweet API data from row #: 528
# Fetching Tweet API data from row #: 529
# Fetching Tweet API data from row #: 530
# Fetching Tweet API data from row #: 531
# Fetching Tweet API data from row #: 532
# Fetching Tweet API data from row #: 533
# Fetching Tweet API data from row #: 534
# Fetching Tweet API data from row #: 535
# Fetching Tweet API data from row #: 536
# Fetching Tweet API data from row #: 537
# Fetching Tweet API data from row #: 538
# Fetching Tweet API data from row #: 539
# Fetching Tweet API data from row #: 540
# Fetching Tweet API data from row #: 541
# Fetching Tweet API data from row #: 542
# Fetching Tweet API data from row #: 543
# Fetching Tweet API data from row #: 544
# Fetching Tweet API data from row #: 545
# Fetching Tweet API data from row #: 546
# Fetching Tweet API data from row #: 547
# Fetching Tweet API data from row #: 548
# Fetching Tweet API data from row #: 549
# Fetching Tweet API data from row #: 550
# Fetching Tweet API data from row #: 551
# Fetching Tweet API data from row #: 552
# Fetching Tweet API data from row #: 553
# Fetching Tweet API data from row #: 554
# Fetching Tweet API data from row #: 555
# Fetching Tweet API data from row #: 556
# Fetching Tweet API data from row #: 557
# Fetching Tweet API data from row #: 558
# Fetching Tweet API data from row #: 559
# Fetching Tweet API data from row #: 560
# Fetching Tweet API data from row #: 561
# Fetching Tweet API data from row #: 562
# Fetching Tweet API data from row #: 563
# Fetching Tweet API data from row #: 564
# Fetching Tweet API data from row #: 565
# Fetching Tweet API data from row #: 566
# Fetching Tweet API data from row #: 567
# The Tweet ID: 802247111496568832 does not exist in the Twitter API
# Trying Retweet ID: 779056095788752896
# The Tweet ID: 779056095788752896 does not exist in the Twitter API
# Trying Tweet ID from the Media URL: 779056095788752897
# Fetching Tweet API data from row #: 568
# Fetching Tweet API data from row #: 569
# Fetching Tweet API data from row #: 570
# Fetching Tweet API data from row #: 572
# Fetching Tweet API data from row #: 573
# Fetching Tweet API data from row #: 574
# Fetching Tweet API data from row #: 575
# Fetching Tweet API data from row #: 576
# Fetching Tweet API data from row #: 578
# Fetching Tweet API data from row #: 579
# Fetching Tweet API data from row #: 580
# Fetching Tweet API data from row #: 581
# Fetching Tweet API data from row #: 582
# Fetching Tweet API data from row #: 583
# Fetching Tweet API data from row #: 584
# Fetching Tweet API data from row #: 585
# Fetching Tweet API data from row #: 586
# Fetching Tweet API data from row #: 587
# Fetching Tweet API data from row #: 588
# Fetching Tweet API data from row #: 589
# Fetching Tweet API data from row #: 590
# Fetching Tweet API data from row #: 591
# Fetching Tweet API data from row #: 592
# Fetching Tweet API data from row #: 593
# Fetching Tweet API data from row #: 594
# Fetching Tweet API data from row #: 595
# Fetching Tweet API data from row #: 596
# Fetching Tweet API data from row #: 597
# Fetching Tweet API data from row #: 598
# Fetching Tweet API data from row #: 599
# Fetching Tweet API data from row #: 600
# Fetching Tweet API data from row #: 601
# Fetching Tweet API data from row #: 602
# Fetching Tweet API data from row #: 603
# Fetching Tweet API data from row #: 604
# Fetching Tweet API data from row #: 605
# Fetching Tweet API data from row #: 606
# Fetching Tweet API data from row #: 607
# Fetching Tweet API data from row #: 608
# Fetching Tweet API data from row #: 609
# Fetching Tweet API data from row #: 610
# Fetching Tweet API data from row #: 611
# Fetching Tweet API data from row #: 613
# Fetching Tweet API data from row #: 614
# Fetching Tweet API data from row #: 615
# Fetching Tweet API data from row #: 616
# Fetching Tweet API data from row #: 617
# Fetching Tweet API data from row #: 618
# Fetching Tweet API data from row #: 619
# Fetching Tweet API data from row #: 620
# Fetching Tweet API data from row #: 621
# Fetching Tweet API data from row #: 622
# Fetching Tweet API data from row #: 623
# Fetching Tweet API data from row #: 624
# Fetching Tweet API data from row #: 625
# Fetching Tweet API data from row #: 626
# Fetching Tweet API data from row #: 627
# Fetching Tweet API data from row #: 628
# Fetching Tweet API data from row #: 629
# Fetching Tweet API data from row #: 630
# Fetching Tweet API data from row #: 631
# Fetching Tweet API data from row #: 632
# Fetching Tweet API data from row #: 633
# Fetching Tweet API data from row #: 634
# Fetching Tweet API data from row #: 635
# Fetching Tweet API data from row #: 636
# Fetching Tweet API data from row #: 637
# Fetching Tweet API data from row #: 638
# Fetching Tweet API data from row #: 639
# Fetching Tweet API data from row #: 640
# Fetching Tweet API data from row #: 641
# Fetching Tweet API data from row #: 642
# Fetching Tweet API data from row #: 643
# Fetching Tweet API data from row #: 644
# Fetching Tweet API data from row #: 645
# Fetching Tweet API data from row #: 646
# Fetching Tweet API data from row #: 647
# Fetching Tweet API data from row #: 648
# Fetching Tweet API data from row #: 649
# Fetching Tweet API data from row #: 650
# Fetching Tweet API data from row #: 651
# Fetching Tweet API data from row #: 652
# Fetching Tweet API data from row #: 653
# Fetching Tweet API data from row #: 654
# Fetching Tweet API data from row #: 655
# Fetching Tweet API data from row #: 656
# Fetching Tweet API data from row #: 657
# Fetching Tweet API data from row #: 658
# Fetching Tweet API data from row #: 659
# Fetching Tweet API data from row #: 660
# Fetching Tweet API data from row #: 661
# Fetching Tweet API data from row #: 662
# Fetching Tweet API data from row #: 663
# Fetching Tweet API data from row #: 664
# Fetching Tweet API data from row #: 665
# Fetching Tweet API data from row #: 666
# Fetching Tweet API data from row #: 667
# Fetching Tweet API data from row #: 668
# Fetching Tweet API data from row #: 669
# Fetching Tweet API data from row #: 670
# Fetching Tweet API data from row #: 671
# Fetching Tweet API data from row #: 672
# Fetching Tweet API data from row #: 673
# Fetching Tweet API data from row #: 674
# Fetching Tweet API data from row #: 675
# Fetching Tweet API data from row #: 676
# Fetching Tweet API data from row #: 677
# Fetching Tweet API data from row #: 678
# Fetching Tweet API data from row #: 679
# Fetching Tweet API data from row #: 680
# Fetching Tweet API data from row #: 681
# Fetching Tweet API data from row #: 682
# Fetching Tweet API data from row #: 683
# Fetching Tweet API data from row #: 684
# Fetching Tweet API data from row #: 685
# Fetching Tweet API data from row #: 686
# Fetching Tweet API data from row #: 687
# Fetching Tweet API data from row #: 688
# Fetching Tweet API data from row #: 689
# Fetching Tweet API data from row #: 690
# Fetching Tweet API data from row #: 691
# Fetching Tweet API data from row #: 692
# Fetching Tweet API data from row #: 693
# Fetching Tweet API data from row #: 694
# Fetching Tweet API data from row #: 695
# Fetching Tweet API data from row #: 697
# Fetching Tweet API data from row #: 698
# Fetching Tweet API data from row #: 699
# Fetching Tweet API data from row #: 700
# Fetching Tweet API data from row #: 701
# Fetching Tweet API data from row #: 703
# Fetching Tweet API data from row #: 704
# Fetching Tweet API data from row #: 705
# Fetching Tweet API data from row #: 706
# Fetching Tweet API data from row #: 707
# Fetching Tweet API data from row #: 709
# Fetching Tweet API data from row #: 710
# Fetching Tweet API data from row #: 711
# Fetching Tweet API data from row #: 712
# Fetching Tweet API data from row #: 713
# Fetching Tweet API data from row #: 714
# Fetching Tweet API data from row #: 715
# Fetching Tweet API data from row #: 716
# Fetching Tweet API data from row #: 717
# Fetching Tweet API data from row #: 718
# Fetching Tweet API data from row #: 719
# Fetching Tweet API data from row #: 720
# Fetching Tweet API data from row #: 721
# Fetching Tweet API data from row #: 722
# Fetching Tweet API data from row #: 723
# Fetching Tweet API data from row #: 724
# Fetching Tweet API data from row #: 725
# Fetching Tweet API data from row #: 726
# Fetching Tweet API data from row #: 727
# Fetching Tweet API data from row #: 728
# Fetching Tweet API data from row #: 729
# Fetching Tweet API data from row #: 730
# Fetching Tweet API data from row #: 731
# Fetching Tweet API data from row #: 732
# Fetching Tweet API data from row #: 733
# Fetching Tweet API data from row #: 734
# Fetching Tweet API data from row #: 735
# Fetching Tweet API data from row #: 736
# Fetching Tweet API data from row #: 737
# Fetching Tweet API data from row #: 738
# Fetching Tweet API data from row #: 739
# Fetching Tweet API data from row #: 740
# Fetching Tweet API data from row #: 741
# Fetching Tweet API data from row #: 742
# Fetching Tweet API data from row #: 743
# Fetching Tweet API data from row #: 744
# Fetching Tweet API data from row #: 745
# Fetching Tweet API data from row #: 746
# Fetching Tweet API data from row #: 747
# Fetching Tweet API data from row #: 748
# Fetching Tweet API data from row #: 749
# Fetching Tweet API data from row #: 750
# Fetching Tweet API data from row #: 751
# Fetching Tweet API data from row #: 752
# Fetching Tweet API data from row #: 753
# Fetching Tweet API data from row #: 754
# Fetching Tweet API data from row #: 755
# Fetching Tweet API data from row #: 756
# Fetching Tweet API data from row #: 757
# Fetching Tweet API data from row #: 758
# Fetching Tweet API data from row #: 759
# Fetching Tweet API data from row #: 760
# Fetching Tweet API data from row #: 761
# Fetching Tweet API data from row #: 762
# Fetching Tweet API data from row #: 763
# Fetching Tweet API data from row #: 764
# Fetching Tweet API data from row #: 765
# Fetching Tweet API data from row #: 766
# Fetching Tweet API data from row #: 767
# Fetching Tweet API data from row #: 768
# Fetching Tweet API data from row #: 769
# Fetching Tweet API data from row #: 770
# Fetching Tweet API data from row #: 771
# Fetching Tweet API data from row #: 772
# Fetching Tweet API data from row #: 773
# Fetching Tweet API data from row #: 774
# Fetching Tweet API data from row #: 775
# Fetching Tweet API data from row #: 776
# Fetching Tweet API data from row #: 777
# Fetching Tweet API data from row #: 778
# Fetching Tweet API data from row #: 779
# Fetching Tweet API data from row #: 780
# Fetching Tweet API data from row #: 781
# Fetching Tweet API data from row #: 782
# Fetching Tweet API data from row #: 783
# Fetching Tweet API data from row #: 784
# Fetching Tweet API data from row #: 785
# The Tweet ID: 775096608509886464 does not exist in the Twitter API
# Trying Retweet ID: 740373189193256960
# The Tweet ID: 740373189193256960 does not exist in the Twitter API
# Trying Tweet ID from the Media URL: 740373189193256964
# Fetching Tweet API data from row #: 786
# Fetching Tweet API data from row #: 787
# Fetching Tweet API data from row #: 788
# Fetching Tweet API data from row #: 789
# Fetching Tweet API data from row #: 790
# Fetching Tweet API data from row #: 791
# Fetching Tweet API data from row #: 792
# Fetching Tweet API data from row #: 793
# Fetching Tweet API data from row #: 794
# Fetching Tweet API data from row #: 795
# Fetching Tweet API data from row #: 796
# Fetching Tweet API data from row #: 797
# Fetching Tweet API data from row #: 798
# Fetching Tweet API data from row #: 799
# Fetching Tweet API data from row #: 800
# Fetching Tweet API data from row #: 801
# Fetching Tweet API data from row #: 802
# Fetching Tweet API data from row #: 803
# Fetching Tweet API data from row #: 804
# Fetching Tweet API data from row #: 805
# Fetching Tweet API data from row #: 806
# Fetching Tweet API data from row #: 807
# Fetching Tweet API data from row #: 808
# Fetching Tweet API data from row #: 809
# Fetching Tweet API data from row #: 810
# Fetching Tweet API data from row #: 811
# Fetching Tweet API data from row #: 812
# Fetching Tweet API data from row #: 813
# Fetching Tweet API data from row #: 814
# Fetching Tweet API data from row #: 815
# Fetching Tweet API data from row #: 816
# Fetching Tweet API data from row #: 817
# Fetching Tweet API data from row #: 818
# Fetching Tweet API data from row #: 819
# The Tweet ID: 770743923962707968 does not exist in the Twitter API
# Trying Retweet ID: 739238157791694848
# The Tweet ID: 739238157791694848 does not exist in the Twitter API
# Trying Tweet ID from the Media URL: 739238157791694849
# Fetching Tweet API data from row #: 820
# Fetching Tweet API data from row #: 821
# Fetching Tweet API data from row #: 822
# Fetching Tweet API data from row #: 823
# Fetching Tweet API data from row #: 824
# Fetching Tweet API data from row #: 825
# Fetching Tweet API data from row #: 826
# Fetching Tweet API data from row #: 827
# Fetching Tweet API data from row #: 828
# Fetching Tweet API data from row #: 829
# Fetching Tweet API data from row #: 830
# Fetching Tweet API data from row #: 831
# Fetching Tweet API data from row #: 832
# Fetching Tweet API data from row #: 833
# Fetching Tweet API data from row #: 834
# Fetching Tweet API data from row #: 835
# Fetching Tweet API data from row #: 836
# Fetching Tweet API data from row #: 837
# Fetching Tweet API data from row #: 838
# Fetching Tweet API data from row #: 839
# Fetching Tweet API data from row #: 840
# Fetching Tweet API data from row #: 841
# Fetching Tweet API data from row #: 842
# Fetching Tweet API data from row #: 843
# Fetching Tweet API data from row #: 845
# Fetching Tweet API data from row #: 846
# Fetching Tweet API data from row #: 847
# Fetching Tweet API data from row #: 848
# Fetching Tweet API data from row #: 849
# Fetching Tweet API data from row #: 850
# Fetching Tweet API data from row #: 851
# Fetching Tweet API data from row #: 852
# Fetching Tweet API data from row #: 853
# Fetching Tweet API data from row #: 854
# Fetching Tweet API data from row #: 855
# Fetching Tweet API data from row #: 856
# Fetching Tweet API data from row #: 857
# Fetching Tweet API data from row #: 859
# Fetching Tweet API data from row #: 860
# Fetching Tweet API data from row #: 861
# Fetching Tweet API data from row #: 862
# Fetching Tweet API data from row #: 863
# Fetching Tweet API data from row #: 864
# Fetching Tweet API data from row #: 865
# Fetching Tweet API data from row #: 866
# Fetching Tweet API data from row #: 867
# Fetching Tweet API data from row #: 868
# Fetching Tweet API data from row #: 869
# Fetching Tweet API data from row #: 870
# Fetching Tweet API data from row #: 871
# Fetching Tweet API data from row #: 872
# Fetching Tweet API data from row #: 873
# Fetching Tweet API data from row #: 874
# Fetching Tweet API data from row #: 875
# Fetching Tweet API data from row #: 876
# Fetching Tweet API data from row #: 877
# Fetching Tweet API data from row #: 878
# Fetching Tweet API data from row #: 879
# Fetching Tweet API data from row #: 880
# Fetching Tweet API data from row #: 881
# Fetching Tweet API data from row #: 882
# Fetching Tweet API data from row #: 883
# Fetching Tweet API data from row #: 884
# Fetching Tweet API data from row #: 885
# Fetching Tweet API data from row #: 886
# Fetching Tweet API data from row #: 887
# Fetching Tweet API data from row #: 888
# Fetching Tweet API data from row #: 889
# Fetching Tweet API data from row #: 890
# Fetching Tweet API data from row #: 891
# Fetching Tweet API data from row #: 892
# Fetching Tweet API data from row #: 893
# Fetching Tweet API data from row #: 894
# Fetching Tweet API data from row #: 895
# Fetching Tweet API data from row #: 896
# Fetching Tweet API data from row #: 897
# Fetching Tweet API data from row #: 898
# Fetching Tweet API data from row #: 899
# Fetching Tweet API data from row #: 900
# Fetching Tweet API data from row #: 901
# Fetching Tweet API data from row #: 902
# Fetching Tweet API data from row #: 903
# Fetching Tweet API data from row #: 904
# Fetching Tweet API data from row #: 905
# Fetching Tweet API data from row #: 906
# Fetching Tweet API data from row #: 907
# Fetching Tweet API data from row #: 908
# Fetching Tweet API data from row #: 909
# Fetching Tweet API data from row #: 910
# Rate limit reached. Sleeping for: 741
# Fetching Tweet API data from row #: 911
# The Tweet ID: 757611664640446465 does not exist in the Twitter API
# Trying Tweet ID from the Media URL: 757611664640446465
# Fetching Tweet API data from row #: 912
# Fetching Tweet API data from row #: 913
# Fetching Tweet API data from row #: 914
# Fetching Tweet API data from row #: 915
# Fetching Tweet API data from row #: 916
# Fetching Tweet API data from row #: 917
# Fetching Tweet API data from row #: 918
# Fetching Tweet API data from row #: 919
# Fetching Tweet API data from row #: 920
# Fetching Tweet API data from row #: 921
# Fetching Tweet API data from row #: 922
# Fetching Tweet API data from row #: 923
# Fetching Tweet API data from row #: 924
# Fetching Tweet API data from row #: 925
# Fetching Tweet API data from row #: 926
# Fetching Tweet API data from row #: 927
# Fetching Tweet API data from row #: 928
# Fetching Tweet API data from row #: 929
# Fetching Tweet API data from row #: 930
# Fetching Tweet API data from row #: 931
# Fetching Tweet API data from row #: 932
# Fetching Tweet API data from row #: 933
# The Tweet ID: 754011816964026368 does not exist in the Twitter API
# Trying Tweet ID from the Media URL: 754011816964026368
# The Tweet ID: 754011816964026368 does not exist in the Twitter API
# Unable to fetch Tweet IDs
# Fetching Tweet API data from row #: 934
# Fetching Tweet API data from row #: 935
# Fetching Tweet API data from row #: 936
# Fetching Tweet API data from row #: 937
# Fetching Tweet API data from row #: 938
# Fetching Tweet API data from row #: 939
# Fetching Tweet API data from row #: 940
# Fetching Tweet API data from row #: 941
# Fetching Tweet API data from row #: 942
# Fetching Tweet API data from row #: 943
# Fetching Tweet API data from row #: 944
# Fetching Tweet API data from row #: 945
# Fetching Tweet API data from row #: 946
# Fetching Tweet API data from row #: 947
# Fetching Tweet API data from row #: 948
# Fetching Tweet API data from row #: 949
# Fetching Tweet API data from row #: 950
# Fetching Tweet API data from row #: 951
# Fetching Tweet API data from row #: 952
# Fetching Tweet API data from row #: 953
# Fetching Tweet API data from row #: 954
# Fetching Tweet API data from row #: 955
# Fetching Tweet API data from row #: 956
# Fetching Tweet API data from row #: 957
# Fetching Tweet API data from row #: 958
# Fetching Tweet API data from row #: 959
# Fetching Tweet API data from row #: 960
# Fetching Tweet API data from row #: 961
# Fetching Tweet API data from row #: 962
# Fetching Tweet API data from row #: 963
# Fetching Tweet API data from row #: 964
# Fetching Tweet API data from row #: 965
# Fetching Tweet API data from row #: 966
# Fetching Tweet API data from row #: 967
# Fetching Tweet API data from row #: 969
# Fetching Tweet API data from row #: 970
# Fetching Tweet API data from row #: 971
# Fetching Tweet API data from row #: 972
# Fetching Tweet API data from row #: 973
# Fetching Tweet API data from row #: 974
# Fetching Tweet API data from row #: 975
# Fetching Tweet API data from row #: 976
# Fetching Tweet API data from row #: 977
# Fetching Tweet API data from row #: 978
# Fetching Tweet API data from row #: 979
# Fetching Tweet API data from row #: 981
# Fetching Tweet API data from row #: 982
# Fetching Tweet API data from row #: 983
# Fetching Tweet API data from row #: 984
# Fetching Tweet API data from row #: 985
# Fetching Tweet API data from row #: 986
# Fetching Tweet API data from row #: 987
# Fetching Tweet API data from row #: 988
# Fetching Tweet API data from row #: 989
# Fetching Tweet API data from row #: 990
# Fetching Tweet API data from row #: 991
# Fetching Tweet API data from row #: 992
# Fetching Tweet API data from row #: 993
# Fetching Tweet API data from row #: 994
# Fetching Tweet API data from row #: 995
# Fetching Tweet API data from row #: 996
# Fetching Tweet API data from row #: 997
# Fetching Tweet API data from row #: 998
# Fetching Tweet API data from row #: 999
# Fetching Tweet API data from row #: 1000
# Fetching Tweet API data from row #: 1001
# Fetching Tweet API data from row #: 1002
# Fetching Tweet API data from row #: 1003
# Fetching Tweet API data from row #: 1004
# Fetching Tweet API data from row #: 1005
# Fetching Tweet API data from row #: 1007
# Fetching Tweet API data from row #: 1008
# Fetching Tweet API data from row #: 1009
# Fetching Tweet API data from row #: 1010
# Fetching Tweet API data from row #: 1011
# Fetching Tweet API data from row #: 1012
# Fetching Tweet API data from row #: 1013
# Fetching Tweet API data from row #: 1014
# Fetching Tweet API data from row #: 1015
# Fetching Tweet API data from row #: 1016
# Fetching Tweet API data from row #: 1017
# Fetching Tweet API data from row #: 1018
# Fetching Tweet API data from row #: 1019
# Fetching Tweet API data from row #: 1020
# Fetching Tweet API data from row #: 1021
# Fetching Tweet API data from row #: 1022
# Fetching Tweet API data from row #: 1023
# Fetching Tweet API data from row #: 1024
# Fetching Tweet API data from row #: 1025
# Fetching Tweet API data from row #: 1026
# Fetching Tweet API data from row #: 1027
# Fetching Tweet API data from row #: 1028
# Fetching Tweet API data from row #: 1029
# Fetching Tweet API data from row #: 1030
# Fetching Tweet API data from row #: 1031
# Fetching Tweet API data from row #: 1032
# Fetching Tweet API data from row #: 1033
# Fetching Tweet API data from row #: 1034
# Fetching Tweet API data from row #: 1035
# Fetching Tweet API data from row #: 1036
# Fetching Tweet API data from row #: 1037
# Fetching Tweet API data from row #: 1038
# Fetching Tweet API data from row #: 1039
# Fetching Tweet API data from row #: 1040
# Fetching Tweet API data from row #: 1041
# Fetching Tweet API data from row #: 1042
# Fetching Tweet API data from row #: 1043
# Fetching Tweet API data from row #: 1044
# Fetching Tweet API data from row #: 1045
# Fetching Tweet API data from row #: 1046
# Fetching Tweet API data from row #: 1047
# Fetching Tweet API data from row #: 1048
# Fetching Tweet API data from row #: 1049
# Fetching Tweet API data from row #: 1050
# Fetching Tweet API data from row #: 1051
# Fetching Tweet API data from row #: 1052
# Fetching Tweet API data from row #: 1053
# Fetching Tweet API data from row #: 1054
# Fetching Tweet API data from row #: 1055
# Fetching Tweet API data from row #: 1056
# Fetching Tweet API data from row #: 1057
# Fetching Tweet API data from row #: 1058
# Fetching Tweet API data from row #: 1059
# Fetching Tweet API data from row #: 1060
# Fetching Tweet API data from row #: 1061
# Fetching Tweet API data from row #: 1062
# Fetching Tweet API data from row #: 1063
# Fetching Tweet API data from row #: 1064
# Fetching Tweet API data from row #: 1065
# Fetching Tweet API data from row #: 1066
# Fetching Tweet API data from row #: 1067
# Fetching Tweet API data from row #: 1068
# Fetching Tweet API data from row #: 1069
# Fetching Tweet API data from row #: 1070
# Fetching Tweet API data from row #: 1071
# Fetching Tweet API data from row #: 1072
# Fetching Tweet API data from row #: 1073
# Fetching Tweet API data from row #: 1074
# Fetching Tweet API data from row #: 1075
# Fetching Tweet API data from row #: 1076
# Fetching Tweet API data from row #: 1077
# Fetching Tweet API data from row #: 1078
# Fetching Tweet API data from row #: 1079
# Fetching Tweet API data from row #: 1080
# Fetching Tweet API data from row #: 1082
# Fetching Tweet API data from row #: 1083
# Fetching Tweet API data from row #: 1084
# Fetching Tweet API data from row #: 1085
# Fetching Tweet API data from row #: 1086
# Fetching Tweet API data from row #: 1087
# Fetching Tweet API data from row #: 1088
# Fetching Tweet API data from row #: 1089
# Fetching Tweet API data from row #: 1090
# Fetching Tweet API data from row #: 1091
# Fetching Tweet API data from row #: 1092
# Fetching Tweet API data from row #: 1093
# Fetching Tweet API data from row #: 1094
# Fetching Tweet API data from row #: 1095
# Fetching Tweet API data from row #: 1096
# Fetching Tweet API data from row #: 1097
# Fetching Tweet API data from row #: 1098
# Fetching Tweet API data from row #: 1099
# Fetching Tweet API data from row #: 1100
# Fetching Tweet API data from row #: 1101
# Fetching Tweet API data from row #: 1102
# Fetching Tweet API data from row #: 1103
# Fetching Tweet API data from row #: 1104
# Fetching Tweet API data from row #: 1105
# Fetching Tweet API data from row #: 1106
# Fetching Tweet API data from row #: 1107
# Fetching Tweet API data from row #: 1108
# Fetching Tweet API data from row #: 1109
# Fetching Tweet API data from row #: 1110
# Fetching Tweet API data from row #: 1111
# Fetching Tweet API data from row #: 1112
# Fetching Tweet API data from row #: 1113
# Fetching Tweet API data from row #: 1114
# Fetching Tweet API data from row #: 1115
# Fetching Tweet API data from row #: 1116
# Fetching Tweet API data from row #: 1117
# Fetching Tweet API data from row #: 1118
# Fetching Tweet API data from row #: 1119
# Fetching Tweet API data from row #: 1120
# Fetching Tweet API data from row #: 1121
# Fetching Tweet API data from row #: 1122
# Fetching Tweet API data from row #: 1123
# Fetching Tweet API data from row #: 1124
# Fetching Tweet API data from row #: 1125
# Fetching Tweet API data from row #: 1126
# Fetching Tweet API data from row #: 1127
# Fetching Tweet API data from row #: 1128
# Fetching Tweet API data from row #: 1129
# Fetching Tweet API data from row #: 1130
# Fetching Tweet API data from row #: 1131
# Fetching Tweet API data from row #: 1132
# Fetching Tweet API data from row #: 1133
# Fetching Tweet API data from row #: 1134
# Fetching Tweet API data from row #: 1135
# Fetching Tweet API data from row #: 1136
# Fetching Tweet API data from row #: 1137
# Fetching Tweet API data from row #: 1138
# Fetching Tweet API data from row #: 1139
# Fetching Tweet API data from row #: 1140
# Fetching Tweet API data from row #: 1141
# Fetching Tweet API data from row #: 1142
# Fetching Tweet API data from row #: 1143
# Fetching Tweet API data from row #: 1144
# Fetching Tweet API data from row #: 1145
# Fetching Tweet API data from row #: 1146
# Fetching Tweet API data from row #: 1147
# Fetching Tweet API data from row #: 1148
# Fetching Tweet API data from row #: 1149
# Fetching Tweet API data from row #: 1150
# ...
# Fetching Tweet API data from row #: 1962
# Fetching Tweet API data from row #: 1963
# Fetching Tweet API data from row #: 1964
# Fetching Tweet API data from row #: 1965
# Fetching Tweet API data from row #: 1966
# Fetching Tweet API data from row #: 1967
# Fetching Tweet API data from row #: 1968
# Fetching Tweet API data from row #: 1969
# Fetching Tweet API data from row #: 1970
# Fetching Tweet API data from row #: 1971
# Fetching Tweet API data from row #: 1972
# Fetching Tweet API data from row #: 1973
# Fetching Tweet API data from row #: 1974
# Fetching Tweet API data from row #: 1975
# Fetching Tweet API data from row #: 1976
# Fetching Tweet API data from row #: 1977
# Fetching Tweet API data from row #: 1978
# Fetching Tweet API data from row #: 1979
# Fetching Tweet API data from row #: 1980
# Fetching Tweet API data from row #: 1981
# Fetching Tweet API data from row #: 1982
# Fetching Tweet API data from row #: 1983
# Fetching Tweet API data from row #: 1984
# Fetching Tweet API data from row #: 1985
# Fetching Tweet API data from row #: 1986
# Fetching Tweet API data from row #: 1987
# Fetching Tweet API data from row #: 1988
# Fetching Tweet API data from row #: 1989
# Fetching Tweet API data from row #: 1990
# Fetching Tweet API data from row #: 1991
# Fetching Tweet API data from row #: 1992
# Fetching Tweet API data from row #: 1993
# Fetching Tweet API data from row #: 1994
# Fetching Tweet API data from row #: 1995
# Fetching Tweet API data from row #: 1996
# Fetching Tweet API data from row #: 1997
# Fetching Tweet API data from row #: 1998
# Fetching Tweet API data from row #: 1999
# Fetching Tweet API data from row #: 2000
# Fetching Tweet API data from row #: 2001
# Fetching Tweet API data from row #: 2002
# Fetching Tweet API data from row #: 2003
# Fetching Tweet API data from row #: 2004
# Fetching Tweet API data from row #: 2005
# Fetching Tweet API data from row #: 2006
# Fetching Tweet API data from row #: 2007
# Fetching Tweet API data from row #: 2008
# Fetching Tweet API data from row #: 2009
# Fetching Tweet API data from row #: 2010
# Fetching Tweet API data from row #: 2011
# Fetching Tweet API data from row #: 2012
# Fetching Tweet API data from row #: 2013
# Fetching Tweet API data from row #: 2014
# Fetching Tweet API data from row #: 2015
# Fetching Tweet API data from row #: 2016
# Fetching Tweet API data from row #: 2017
# Fetching Tweet API data from row #: 2018
# Fetching Tweet API data from row #: 2019
# Fetching Tweet API data from row #: 2020
# Fetching Tweet API data from row #: 2021
# Fetching Tweet API data from row #: 2022
# Fetching Tweet API data from row #: 2023
# Fetching Tweet API data from row #: 2024
# Fetching Tweet API data from row #: 2025
# Fetching Tweet API data from row #: 2026
# Fetching Tweet API data from row #: 2027
# Fetching Tweet API data from row #: 2028
# Fetching Tweet API data from row #: 2029
# Fetching Tweet API data from row #: 2030
# Fetching Tweet API data from row #: 2031
# Fetching Tweet API data from row #: 2032
# Fetching Tweet API data from row #: 2033
# Fetching Tweet API data from row #: 2034
# Fetching Tweet API data from row #: 2035
# Fetching Tweet API data from row #: 2036
# Fetching Tweet API data from row #: 2037
# Fetching Tweet API data from row #: 2038
# Fetching Tweet API data from row #: 2040
# Fetching Tweet API data from row #: 2041
# Fetching Tweet API data from row #: 2042
# Fetching Tweet API data from row #: 2043
# Fetching Tweet API data from row #: 2044
# Fetching Tweet API data from row #: 2045
# Fetching Tweet API data from row #: 2046
# Fetching Tweet API data from row #: 2047
# Fetching Tweet API data from row #: 2048
# Fetching Tweet API data from row #: 2049
# Fetching Tweet API data from row #: 2050
# Fetching Tweet API data from row #: 2051
# Fetching Tweet API data from row #: 2052
# Fetching Tweet API data from row #: 2053
# Fetching Tweet API data from row #: 2054
# Fetching Tweet API data from row #: 2055
# Fetching Tweet API data from row #: 2056
# Fetching Tweet API data from row #: 2057
# Fetching Tweet API data from row #: 2058
# Fetching Tweet API data from row #: 2059
# Fetching Tweet API data from row #: 2060
# Fetching Tweet API data from row #: 2061
# Fetching Tweet API data from row #: 2062
# Fetching Tweet API data from row #: 2063
# Fetching Tweet API data from row #: 2064
# Fetching Tweet API data from row #: 2065
# Fetching Tweet API data from row #: 2066
# Fetching Tweet API data from row #: 2067
# Fetching Tweet API data from row #: 2068
# Fetching Tweet API data from row #: 2069
# Fetching Tweet API data from row #: 2070
# Fetching Tweet API data from row #: 2071
# Fetching Tweet API data from row #: 2072
# Fetching Tweet API data from row #: 2073
# Fetching Tweet API data from row #: 2074
# Fetching Tweet API data from row #: 2076
# Fetching Tweet API data from row #: 2077
# Fetching Tweet API data from row #: 2078
# Fetching Tweet API data from row #: 2079
# Fetching Tweet API data from row #: 2080
# Fetching Tweet API data from row #: 2081
# Fetching Tweet API data from row #: 2082
# Fetching Tweet API data from row #: 2083
# Fetching Tweet API data from row #: 2084
# Fetching Tweet API data from row #: 2085
# Fetching Tweet API data from row #: 2086
# Fetching Tweet API data from row #: 2087
# Fetching Tweet API data from row #: 2088
# Fetching Tweet API data from row #: 2089
# Fetching Tweet API data from row #: 2090
# Fetching Tweet API data from row #: 2091
# Fetching Tweet API data from row #: 2092
# Fetching Tweet API data from row #: 2093
# Fetching Tweet API data from row #: 2094
# Fetching Tweet API data from row #: 2095
# Fetching Tweet API data from row #: 2096
# Fetching Tweet API data from row #: 2097
# Fetching Tweet API data from row #: 2098
# Fetching Tweet API data from row #: 2099
# Fetching Tweet API data from row #: 2100
# Fetching Tweet API data from row #: 2101
# Fetching Tweet API data from row #: 2102
# Fetching Tweet API data from row #: 2103
# Fetching Tweet API data from row #: 2104
# Fetching Tweet API data from row #: 2105
# Fetching Tweet API data from row #: 2106
# Fetching Tweet API data from row #: 2107
# Fetching Tweet API data from row #: 2108
# Fetching Tweet API data from row #: 2109
# Fetching Tweet API data from row #: 2110
# Fetching Tweet API data from row #: 2111
# Fetching Tweet API data from row #: 2112
# Fetching Tweet API data from row #: 2113
# Fetching Tweet API data from row #: 2114
# Fetching Tweet API data from row #: 2115
# Fetching Tweet API data from row #: 2116
# Fetching Tweet API data from row #: 2117
# Fetching Tweet API data from row #: 2118
# Fetching Tweet API data from row #: 2119
# Fetching Tweet API data from row #: 2120
# Fetching Tweet API data from row #: 2121
# Fetching Tweet API data from row #: 2122
# Fetching Tweet API data from row #: 2123
# Fetching Tweet API data from row #: 2124
# Fetching Tweet API data from row #: 2125
# Fetching Tweet API data from row #: 2126
# Fetching Tweet API data from row #: 2127
# Fetching Tweet API data from row #: 2128
# Fetching Tweet API data from row #: 2129
# Fetching Tweet API data from row #: 2130
# Fetching Tweet API data from row #: 2131
# Fetching Tweet API data from row #: 2132
# Fetching Tweet API data from row #: 2133
# Fetching Tweet API data from row #: 2134
# Fetching Tweet API data from row #: 2135
# Fetching Tweet API data from row #: 2136
# Fetching Tweet API data from row #: 2137
# Fetching Tweet API data from row #: 2138
# Fetching Tweet API data from row #: 2139
# Fetching Tweet API data from row #: 2140
# Fetching Tweet API data from row #: 2141
# Fetching Tweet API data from row #: 2142
# Fetching Tweet API data from row #: 2143
# Fetching Tweet API data from row #: 2144
# Fetching Tweet API data from row #: 2145
# Fetching Tweet API data from row #: 2146
# Fetching Tweet API data from row #: 2147
# Fetching Tweet API data from row #: 2148
# Fetching Tweet API data from row #: 2149
# Fetching Tweet API data from row #: 2151
# Fetching Tweet API data from row #: 2152
# Fetching Tweet API data from row #: 2153
# Fetching Tweet API data from row #: 2154
# Fetching Tweet API data from row #: 2155
# Fetching Tweet API data from row #: 2156
# Fetching Tweet API data from row #: 2157
# Fetching Tweet API data from row #: 2158
# Fetching Tweet API data from row #: 2159
# Fetching Tweet API data from row #: 2160
# Fetching Tweet API data from row #: 2161
# Fetching Tweet API data from row #: 2162
# Fetching Tweet API data from row #: 2163
# Fetching Tweet API data from row #: 2164
# Fetching Tweet API data from row #: 2165
# Fetching Tweet API data from row #: 2166
# Fetching Tweet API data from row #: 2167
# Fetching Tweet API data from row #: 2168
# Fetching Tweet API data from row #: 2169
# Fetching Tweet API data from row #: 2170
# Fetching Tweet API data from row #: 2171
# Fetching Tweet API data from row #: 2172
# Fetching Tweet API data from row #: 2173
# Fetching Tweet API data from row #: 2174
# Fetching Tweet API data from row #: 2175
# Fetching Tweet API data from row #: 2176
# Fetching Tweet API data from row #: 2177
# Fetching Tweet API data from row #: 2178
# Fetching Tweet API data from row #: 2179
# Fetching Tweet API data from row #: 2180
# Fetching Tweet API data from row #: 2181
# Fetching Tweet API data from row #: 2182
# Fetching Tweet API data from row #: 2183
# Fetching Tweet API data from row #: 2184
# Fetching Tweet API data from row #: 2185
# Fetching Tweet API data from row #: 2186
# Fetching Tweet API data from row #: 2187
# Fetching Tweet API data from row #: 2188
# Fetching Tweet API data from row #: 2189
# Fetching Tweet API data from row #: 2191
# Fetching Tweet API data from row #: 2192
# Fetching Tweet API data from row #: 2193
# Fetching Tweet API data from row #: 2194
# Fetching Tweet API data from row #: 2195
# Fetching Tweet API data from row #: 2196
# Fetching Tweet API data from row #: 2197
# Fetching Tweet API data from row #: 2198
# Fetching Tweet API data from row #: 2199
# Fetching Tweet API data from row #: 2200
# Fetching Tweet API data from row #: 2201
# Fetching Tweet API data from row #: 2202
# Fetching Tweet API data from row #: 2203
# Fetching Tweet API data from row #: 2204
# Fetching Tweet API data from row #: 2205
# Fetching Tweet API data from row #: 2206
# Fetching Tweet API data from row #: 2207
# Fetching Tweet API data from row #: 2208
# Fetching Tweet API data from row #: 2209
# Fetching Tweet API data from row #: 2210
# Fetching Tweet API data from row #: 2211
# Fetching Tweet API data from row #: 2212
# Fetching Tweet API data from row #: 2213
# Fetching Tweet API data from row #: 2214
# Fetching Tweet API data from row #: 2215
# Fetching Tweet API data from row #: 2216
# Fetching Tweet API data from row #: 2217
# Fetching Tweet API data from row #: 2218
# Fetching Tweet API data from row #: 2219
# Fetching Tweet API data from row #: 2220
# Fetching Tweet API data from row #: 2221
# Fetching Tweet API data from row #: 2222
# Fetching Tweet API data from row #: 2223
# Fetching Tweet API data from row #: 2224
# Fetching Tweet API data from row #: 2225
# Fetching Tweet API data from row #: 2226
# Fetching Tweet API data from row #: 2227
# Fetching Tweet API data from row #: 2228
# Fetching Tweet API data from row #: 2229
# Fetching Tweet API data from row #: 2230
# Fetching Tweet API data from row #: 2231
# Fetching Tweet API data from row #: 2232
# Fetching Tweet API data from row #: 2233
# Fetching Tweet API data from row #: 2234
# Fetching Tweet API data from row #: 2235
# Fetching Tweet API data from row #: 2236
# Fetching Tweet API data from row #: 2237
# Fetching Tweet API data from row #: 2238
# Fetching Tweet API data from row #: 2239
# Fetching Tweet API data from row #: 2240
# Fetching Tweet API data from row #: 2241
# Fetching Tweet API data from row #: 2242
# Fetching Tweet API data from row #: 2243
# Fetching Tweet API data from row #: 2244
# Fetching Tweet API data from row #: 2245
# Fetching Tweet API data from row #: 2246
# Fetching Tweet API data from row #: 2247
# Fetching Tweet API data from row #: 2248
# Fetching Tweet API data from row #: 2249
# Fetching Tweet API data from row #: 2250
# Fetching Tweet API data from row #: 2251
# Fetching Tweet API data from row #: 2252
# Fetching Tweet API data from row #: 2253
# Fetching Tweet API data from row #: 2254
# Fetching Tweet API data from row #: 2255
# Fetching Tweet API data from row #: 2256
# Fetching Tweet API data from row #: 2257
# Fetching Tweet API data from row #: 2258
# Fetching Tweet API data from row #: 2259
# Fetching Tweet API data from row #: 2260
# Fetching Tweet API data from row #: 2261
# Fetching Tweet API data from row #: 2262
# Fetching Tweet API data from row #: 2263
# Fetching Tweet API data from row #: 2264
# Fetching Tweet API data from row #: 2265
# Fetching Tweet API data from row #: 2266
# Fetching Tweet API data from row #: 2267
# Fetching Tweet API data from row #: 2268
# Fetching Tweet API data from row #: 2269
# Fetching Tweet API data from row #: 2270
# Fetching Tweet API data from row #: 2271
# Fetching Tweet API data from row #: 2272
# Fetching Tweet API data from row #: 2273
# Fetching Tweet API data from row #: 2274
# Fetching Tweet API data from row #: 2275
# Fetching Tweet API data from row #: 2276
# Fetching Tweet API data from row #: 2277
# Fetching Tweet API data from row #: 2278
# Fetching Tweet API data from row #: 2279
# Fetching Tweet API data from row #: 2280
# Fetching Tweet API data from row #: 2281
# Fetching Tweet API data from row #: 2282
# Fetching Tweet API data from row #: 2283
# Fetching Tweet API data from row #: 2284
# Fetching Tweet API data from row #: 2285
# Fetching Tweet API data from row #: 2286
# Fetching Tweet API data from row #: 2287
# Fetching Tweet API data from row #: 2288
# Fetching Tweet API data from row #: 2289
# Fetching Tweet API data from row #: 2290
# Fetching Tweet API data from row #: 2291
# Fetching Tweet API data from row #: 2292
# Fetching Tweet API data from row #: 2293
# Fetching Tweet API data from row #: 2294
# Fetching Tweet API data from row #: 2295
# Fetching Tweet API data from row #: 2296
# Fetching Tweet API data from row #: 2297
# Fetching Tweet API data from row #: 2298
# Fetching Tweet API data from row #: 2300
# Fetching Tweet API data from row #: 2301
# Fetching Tweet API data from row #: 2302
# Fetching Tweet API data from row #: 2303
# Fetching Tweet API data from row #: 2304
# Fetching Tweet API data from row #: 2305
# Fetching Tweet API data from row #: 2306
# Fetching Tweet API data from row #: 2307
# Fetching Tweet API data from row #: 2308
# Fetching Tweet API data from row #: 2309
# Fetching Tweet API data from row #: 2310
# Fetching Tweet API data from row #: 2311
# Fetching Tweet API data from row #: 2312
# Fetching Tweet API data from row #: 2313
# Fetching Tweet API data from row #: 2314
# Fetching Tweet API data from row #: 2315
# Fetching Tweet API data from row #: 2316
# Fetching Tweet API data from row #: 2317
# Fetching Tweet API data from row #: 2318
# Fetching Tweet API data from row #: 2319
# Fetching Tweet API data from row #: 2320
# Fetching Tweet API data from row #: 2321
# Fetching Tweet API data from row #: 2322
# Fetching Tweet API data from row #: 2323
# Fetching Tweet API data from row #: 2324
# Fetching Tweet API data from row #: 2325
# Fetching Tweet API data from row #: 2326
# Fetching Tweet API data from row #: 2327
# Fetching Tweet API data from row #: 2328
# Fetching Tweet API data from row #: 2329
# Fetching Tweet API data from row #: 2330
# Fetching Tweet API data from row #: 2331
# Fetching Tweet API data from row #: 2332
# Fetching Tweet API data from row #: 2333
# Fetching Tweet API data from row #: 2334
# Fetching Tweet API data from row #: 2335
# Fetching Tweet API data from row #: 2336
# Fetching Tweet API data from row #: 2337
# Fetching Tweet API data from row #: 2338
# Fetching Tweet API data from row #: 2339
# Fetching Tweet API data from row #: 2340
# Fetching Tweet API data from row #: 2341
# Fetching Tweet API data from row #: 2342
# Fetching Tweet API data from row #: 2343
# Fetching Tweet API data from row #: 2344
# Fetching Tweet API data from row #: 2345
# Fetching Tweet API data from row #: 2346
# Fetching Tweet API data from row #: 2347
# Fetching Tweet API data from row #: 2348
# Fetching Tweet API data from row #: 2349
# Fetching Tweet API data from row #: 2350
# Fetching Tweet API data from row #: 2351
# Fetching Tweet API data from row #: 2352
# Fetching Tweet API data from row #: 2353
# Fetching Tweet API data from row #: 2354
# Fetching Tweet API data from row #: 2355
# Fetching Tweet API data from row #: 2356

# %%
write_json_objects_to_txtfile(output_json_obj,"Tweet-json.txt")

# %% [markdown]
# #### Removing the Retweet ID and replies ID columns from the dataframe

# %%
weratedogs_copy = weratedogs_twitter_archive_data.copy()
weratedogs_copy = weratedogs_copy.drop(['in_reply_to_user_id','in_reply_to_status_id','retweeted_status_id'],axis=1)
weratedogs_twitter_archive_data = weratedogs_copy

# %% [markdown]
# ### Getting tweet stats from the Tweets JSON file

# %%
output = []
column_headers = ["tweet_id","retweet_count","favorite_count","retweeted"]
with open("Tweet-json.txt","r") as tweets_file:
    for i,line in enumerate(tweets_file):
        row_obj = dict.fromkeys(column_headers)
        dict_item = json.loads(line)
        if dict_item:
            try:
                row_obj["tweet_id"] = dict_item["id"]
            except KeyError:
                print ("Line Number: ".format(i))
            try:
                row_obj["retweet_count"] = dict_item["retweet_count"]
            except KeyError:
                print ("Line Number: ".format(i))
        
            try:
                row_obj["favorite_count"] = dict_item["favorite_count"]
            except KeyError:
                print ("Line Number: ".format(i))
        
            try:
                row_obj["retweeted"] = dict_item["retweeted"]
            except KeyError:
                print ("Line Number: ".format(i))
        

            output.append(row_obj)

master_df = pd.DataFrame(output)
master_df = master_df[column_headers]

# %%
weratedogs_twitter_archive_data.head()
# Out:
#              tweet_id           timestamp                         source_urls  \
# 0  892420643555336193 2017-08-01 16:23:56  http://twitter.com/download/iphone
# 1  892177421306343426 2017-08-01 00:17:27  http://twitter.com/download/iphone
# 2  891815181378084864 2017-07-31 00:18:03  http://twitter.com/download/iphone
# 3  891689557279858688 2017-07-30 15:58:51  http://twitter.com/download/iphone
# 4  891327558926688256 2017-07-29 16:00:24  http://twitter.com/download/iphone
#
#    source_description                                               text  \
# 0  Twitter for iPhone  This is Phineas. He's a mystical boy. Only eve...
# 1  Twitter for iPhone  This is Tilly. She's just checking pup on you....
# 2  Twitter for iPhone  This is Archie. He is a rare Norwegian Pouncin...
# 3  Twitter for iPhone  This is Darla. She commenced a snooze mid meal...
# 4  Twitter for iPhone  This is Franklin. He would like you to stop ca...
#
#                                        expanded_urls  standardized_rating  \
# 0  https://twitter.com/dog_rates/status/892420643...                   13
# 1  https://twitter.com/dog_rates/status/892177421...                   13
# 2  https://twitter.com/dog_rates/status/891815181...                   12
# 3  https://twitter.com/dog_rates/status/891689557...                   13
# 4  https://twitter.com/dog_rates/status/891327558...                   12
#
#        name dog_stage
# 0   Phineas      None
# 1     Tilly      None
# 2    Archie      None
# 3     Darla      None
# 4  Franklin      None

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2287 entries, 0 to 2286
# Data columns (total 4 columns):
# tweet_id          2287 non-null int64
# retweet_count     2287 non-null int64
# favorite_count    2287 non-null int64
# retweeted         2287 non-null bool
# dtypes: bool(1), int64(3)
# memory usage: 55.9 KB

# %% [markdown]
# **Tidiness**
#
#
# 3. Column 'expanded_urls' contains multiple URLs, some of which are repetitions of the same photo URLs. Remove this column from the twitter archive dataset and create a new dataframe for the mediaURLs.

# %%
weratedogs_copy = weratedogs_twitter_archive_data.copy()
mediaURLs = {}
mediaURLs["tweet_id"] = []
mediaURLs["mediaURL"] = []

for index,row in weratedogs_copy.iterrows():
    if "," in row["expanded_urls"]:
        mediaURLs["mediaURL"].extend(list(set(row["expanded_urls"].split(","))))
        mediaURLs["tweet_id"].extend([row["tweet_id"]]*len(list(set(row["expanded_urls"].split(",")))))
    else:
        mediaURLs["mediaURL"].append(row["expanded_urls"])
        mediaURLs["tweet_id"].append(row["tweet_id"])

mediaURLs = pd.DataFrame(mediaURLs)
mediaURLs.head()
# Out:
#              tweet_id                                           mediaURL
# 0  892420643555336193  https://twitter.com/dog_rates/status/892420643...
# 1  892177421306343426  https://twitter.com/dog_rates/status/892177421...
# 2  891815181378084864  https://twitter.com/dog_rates/status/891815181...
# 3  891689557279858688  https://twitter.com/dog_rates/status/891689557...
# 4  891327558926688256  https://twitter.com/dog_rates/status/891327558...

# %%
mediaURLs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2334 entries, 0 to 2333
# Data columns (total 2 columns):
# tweet_id    2334 non-null int64
# mediaURL    2334 non-null object
# dtypes: int64(1), object(1)
# memory usage: 36.5+ KB

# %%
mediaURLs.to_csv("mediaURLs.csv",index=False)

# %%
weratedogs_copy = weratedogs_copy.drop(columns = ["expanded_urls"])

# %%
weratedogs_copy.head()
# Out:
#              tweet_id           timestamp                         source_urls  \
# 0  892420643555336193 2017-08-01 16:23:56  http://twitter.com/download/iphone
# 1  892177421306343426 2017-08-01 00:17:27  http://twitter.com/download/iphone
# 2  891815181378084864 2017-07-31 00:18:03  http://twitter.com/download/iphone
# 3  891689557279858688 2017-07-30 15:58:51  http://twitter.com/download/iphone
# 4  891327558926688256 2017-07-29 16:00:24  http://twitter.com/download/iphone
#
#    source_description                                               text  \
# 0  Twitter for iPhone  This is Phineas. He's a mystical boy. Only eve...
# 1  Twitter for iPhone  This is Tilly. She's just checking pup on you....
# 2  Twitter for iPhone  This is Archie. He is a rare Norwegian Pouncin...
# 3  Twitter for iPhone  This is Darla. She commenced a snooze mid meal...
# 4  Twitter for iPhone  This is Franklin. He would like you to stop ca...
#
#    standardized_rating      name dog_stage
# 0                   13   Phineas      None
# 1                   13     Tilly      None
# 2                   12    Archie      None
# 3                   13     Darla      None
# 4                   12  Franklin      None

# %%
weratedogs_twitter_archive_data = weratedogs_copy

# %% [markdown]
# ### Assessing the Predictions dataframe

# %%
predictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null object
# jpg_url     2075 non-null object
# img_num     2075 non-null object
# p1          2075 non-null object
# p1_conf     2075 non-null object
# p1_dog      2075 non-null object
# p2          2075 non-null object
# p2_conf     2075 non-null object
# p2_dog      2075 non-null object
# p3          2075 non-null object
# p3_conf     2075 non-null object
# p3_dog      2075 non-null object
# dtypes: object(12)
# memory usage: 194.6+ KB

# %%
predictions.sample(n=50)
# Out:
#                 tweet_id                                            jpg_url  \
# 1119  726224900189511680    https://pbs.twimg.com/media/ChQRsYaW0AETD7z.jpg
# 884   698953797952008193    https://pbs.twimg.com/media/CbMuxV5WEAAIBjy.jpg
# 1039  712085617388212225    https://pbs.twimg.com/media/CeHWFksXIAAyypp.jpg
# 931   703079050210877440    https://pbs.twimg.com/media/CcHWqQCW8AEb0ZH.jpg
# 1138  729113531270991872    https://pbs.twimg.com/media/Ch5U4FzXEAAShhF.jpg
# 1327  757393109802180609    https://pbs.twimg.com/media/CoLNAq6WAAAkmdJ.jpg
# 319   671768281401958400    https://pbs.twimg.com/media/CVKZsHtWwAA6gPj.jpg
# 1432  773308824254029826    https://pbs.twimg.com/media/CrtYRMEWIAAUkCl.jpg
# 1042  712438159032893441    https://pbs.twimg.com/media/CeMWubMWwAA6GwF.jpg
# 1685  814530161257443328    https://pbs.twimg.com/media/C03K2-VWIAAK1iV.jpg
# 679   683742671509258241    https://pbs.twimg.com/media/CX0kVRxWYAAWWZi.jpg
# 77    667437278097252352    https://pbs.twimg.com/media/CUM2qWaWoAUZ06L.jpg
# 595   679511351870550016    https://pbs.twimg.com/media/CW4b-GUWYAAa8QO.jpg
# 1792  830956169170665475  https://pbs.twimg.com/ext_tw_video_thumb/83095...
# 1178  737826014890496000    https://pbs.twimg.com/media/Cj1I1fbWYAAOwff.jpg
# 1526  788765914992902144    https://pbs.twimg.com/media/CvJCabcWgAIoUxW.jpg
# 367   672964561327235073    https://pbs.twimg.com/media/CVbZsouWUAIsxMc.jpg
# 2058  888917238123831296    https://pbs.twimg.com/media/DFYRgsOUQAARGhO.jpg
# 2016  879862464715927552    https://pbs.twimg.com/media/DDXmPrbWAAEKMvy.jpg
# 1412  770787852854652928    https://pbs.twimg.com/media/CrJjdZmXgAEWLSD.jpg
# 32    666428276349472768    https://pbs.twimg.com/media/CT-g-0DUwAEQdSn.jpg
# 759   688804835492233216    https://pbs.twimg.com/media/CY8gWFRWUAAm1XL.jpg
# 2013  879376492567855104    https://pbs.twimg.com/media/DDQsQGFV0AAw6u9.jpg
# 1988  872820683541237760    https://pbs.twimg.com/media/DBzhx0PWAAEhl0E.jpg
# 942   704113298707505153    https://pbs.twimg.com/media/CcWDTerUAAALORn.jpg
# 1538  790723298204217344    https://pbs.twimg.com/media/CvaYgDOWgAEfjls.jpg
# 7     666055525042405380    https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 2010  878776093423087618    https://pbs.twimg.com/media/DDIKMXzW0AEibje.jpg
# 1095  720043174954147842    https://pbs.twimg.com/media/Cf4bcm8XEAAX4xV.jpg
# 961   705898680587526145    https://pbs.twimg.com/media/CcvbGj5W8AARjB6.jpg
# 2023  881536004380872706  https://pbs.twimg.com/ext_tw_video_thumb/88153...
# 1816  833863086058651648    https://pbs.twimg.com/media/C5J6DIpWQAEosSz.jpg
# 253   670727704916926465    https://pbs.twimg.com/media/CU7nSZEW4AA6r5u.jpg
# 1170  736225175608430592    https://pbs.twimg.com/media/CjeY5DKXEAA3WkD.jpg
# 278   670995969505435648    https://pbs.twimg.com/media/CU_bRIEWcAAUVC7.jpg
# 1858  841833993020538882  https://pbs.twimg.com/ext_tw_video_thumb/81742...
# 918   701601587219795968    https://pbs.twimg.com/media/CbyW7B0W8AIX8kX.jpg
# 142   668614819948453888    https://pbs.twimg.com/media/CUdloW8WEAAxB_Y.jpg
# 1253  748307329658011649    https://pbs.twimg.com/media/CmKFi-FXEAAeI37.jpg
# 136   668507509523615744    https://pbs.twimg.com/media/CUcECBYWcAAzFRg.jpg
# 93    667549055577362432    https://pbs.twimg.com/media/CUOcVCwWsAERUKY.jpg
# 1457  777684233540206592    https://pbs.twimg.com/media/CsrjryzWgAAZY00.jpg
# 1594  798697898615730177    https://pbs.twimg.com/media/CeRoBaxWEAABi0X.jpg
# 1987  872620804844003328    https://pbs.twimg.com/media/DBwr_hzXkAEnZBW.jpg
# 1376  763183847194451968    https://pbs.twimg.com/media/CpdfpzKWYAAWSUi.jpg
# 1879  846514051647705089    https://pbs.twimg.com/media/C79sB4xXwAEvwKY.jpg
# 1134  728653952833728512    https://pbs.twimg.com/media/Chyy5lQWUAEzxSL.jpg
# 791   690690673629138944    https://pbs.twimg.com/media/CZXTgKkWwAA5UZJ.jpg
# 236   670428280563085312    https://pbs.twimg.com/media/CU3W9ELWEAEdUA0.jpg
# 280   671115716440031232    https://pbs.twimg.com/media/CVBILUgVAAA1ZUr.jpg
#
#      img_num                    p1               p1_conf p1_dog  \
# 1119       1       standard_poodle              0.261112   True
# 884        1     Italian_greyhound              0.382378   True
# 1039       2              Shih-Tzu              0.625129   True
# 931        2              Pembroke              0.778503   True
# 1138       2            stone_wall    0.6061880000000001  False
# 1327       2    Labrador_retriever              0.787125   True
# 319        2             Chihuahua              0.500373   True
# 1432       1         shopping_cart              0.572349  False
# 1042       1              ice_bear              0.869477  False
# 1685       1      miniature_poodle              0.626913   True
# 679        1              Pembroke              0.895279   True
# 77         1             porcupine    0.9891540000000001  False
# 595        1             Chihuahua              0.761972   True
# 1792       1                kuvasz              0.451516   True
# 1178       1                vizsla              0.990391   True
# 1526       1        cocker_spaniel              0.500509   True
# 367        1             Chihuahua   0.29234299999999996   True
# 2058       1      golden_retriever              0.714719   True
# 2016       3                basset              0.813507   True
# 1412       1  Bernese_mountain_dog              0.787812   True
# 32         1              Pembroke              0.371361   True
# 759        3              malinois              0.199512   True
# 2013       1              tricycle              0.663601  False
# 1988       3                   pug    0.9991200000000001   True
# 942        2                 otter    0.9455370000000001  False
# 1538       1                   tub   0.47947700000000004  False
# 7          1                  chow              0.692517   True
# 2010       2     Italian_greyhound              0.734684   True
# 1095       1               Samoyed    0.9545170000000001   True
# 961        1                collie              0.808276   True
# 2023       1               Samoyed              0.281463   True
# 1816       1                kuvasz   0.49496899999999994   True
# 253        1           wood_rabbit              0.368562  False
# 1170       1    Labrador_retriever              0.399217   True
# 278        1               redbone    0.8662209999999999   True
# 1858       1              ice_bear                0.3362  False
# 918        1             Chihuahua              0.993661   True
# 142        1               bustard              0.380772  False
# 1253       2                paddle              0.589066  False
# 136        1               basenji  0.055379399999999995   True
# 93         1          electric_fan    0.9843770000000001  False
# 1457       1        cocker_spaniel              0.253442   True
# 1594       1    Labrador_retriever    0.8686709999999999   True
# 1987       1        cocker_spaniel              0.513191   True
# 1376       1      miniature_poodle              0.354674   True
# 1879       2      golden_retriever              0.650003   True
# 1134       2          window_shade              0.594333  False
# 791        1            bath_towel   0.19453199999999998  False
# 236        1                  chow              0.335269   True
# 280        1              malinois              0.406341   True
#
#                                p2               p2_conf p2_dog  \
# 1119               cocker_spaniel             0.0947852   True
# 884                       redbone              0.102255   True
# 1039              Tibetan_terrier              0.126897   True
# 931             Shetland_sheepdog             0.0938339   True
# 1138                       prison              0.064831  False
# 1327     Chesapeake_Bay_retriever              0.112676   True
# 319                French_bulldog   0.11279600000000001   True
# 1432           Labrador_retriever   0.15140599999999999   True
# 1042               Great_Pyrenees              0.069457   True
# 1685                   toy_poodle   0.26558200000000004   True
# 679                      Cardigan              0.022385   True
# 77                     bath_towel            0.00630049  False
# 595           black-footed_ferret              0.150605  False
# 1792             golden_retriever              0.317196   True
# 1178          Rhodesian_ridgeback            0.00560474   True
# 1526             golden_retriever   0.27273400000000003   True
# 367                           pug   0.17336400000000002   True
# 2058              Tibetan_mastiff   0.12018399999999999   True
# 2016                       beagle              0.146654   True
# 1412   Greater_Swiss_Mountain_dog              0.163946   True
# 32                           chow              0.249394   True
# 759               German_shepherd             0.0967973   True
# 2013           Labrador_retriever             0.0334961   True
# 1988               French_bulldog            0.00055192   True
# 942                          mink  0.018231099999999997  False
# 1538                      bathtub              0.325106  False
# 7                 Tibetan_mastiff  0.058279399999999995   True
# 2010                      whippet   0.15048699999999998   True
# 1095                   Eskimo_dog             0.0291296   True
# 961                 Border_collie  0.059437000000000004   True
# 2023                       Angora              0.272066  False
# 1816               Great_Pyrenees              0.312632   True
# 253                         tabby              0.309675  False
# 1170  West_Highland_white_terrier               0.13771   True
# 278                        beagle  0.061194000000000005   True
# 1858                      Samoyed   0.20135799999999998   True
# 918                      Pembroke            0.00150487   True
# 142                       pelican   0.10055399999999999  False
# 1253                       shovel   0.03806230000000001  False
# 136             Shetland_sheepdog             0.0543221   True
# 93                      spotlight            0.00773671  False
# 1457             golden_retriever               0.16285   True
# 1594                       carton             0.0950952  False
# 1987               Sussex_spaniel              0.159088   True
# 1376                   toy_poodle              0.338642   True
# 1879                     Leonberg             0.0651992   True
# 1134                 studio_couch              0.053515  False
# 791                      radiator              0.127776  False
# 236              golden_retriever               0.30585   True
# 280                        kelpie   0.14336600000000002   True
#
#                                p3                p3_conf p3_dog
# 1119                       bucket    0.06994639999999999  False
# 884                    shower_cap              0.0768337  False
# 1039                        Lhasa               0.119663   True
# 931                      Cardigan    0.06029640000000001   True
# 1138                    bannister              0.0480482  False
# 1327                   Rottweiler   0.048038599999999994   True
# 319             Italian_greyhound              0.0628927   True
# 1432              shopping_basket               0.107102  False
# 1042           Labrador_retriever                0.02474   True
# 1685  soft-coated_wheaten_terrier              0.0416142   True
# 679                cocker_spaniel              0.0170452   True
# 77                         badger             0.00096634  False
# 595               squirrel_monkey   0.028147900000000003  False
# 1792               English_setter               0.132759   True
# 1178     Chesapeake_Bay_retriever             0.00286936   True
# 1526                jigsaw_puzzle    0.04147580000000001  False
# 367                French_bulldog   0.045507099999999995   True
# 2058           Labrador_retriever    0.10550599999999999   True
# 2016               cocker_spaniel             0.00948502   True
# 1412                  EntleBucher   0.020293400000000003   True
# 32                     Pomeranian               0.241878   True
# 759                        Saluki              0.0828482   True
# 2013                     Pembroke              0.0188266   True
# 1988                 bull_mastiff            7.28904e-05   True
# 942                      sea_lion              0.0158608  False
# 1538             golden_retriever    0.07853049999999999   True
# 7                        fur_coat              0.0544486  False
# 2010                 Ibizan_hound              0.0397246   True
# 1095                   white_wolf             0.00446203  False
# 961                   groenendael              0.0267203   True
# 2023                  Persian_cat               0.114854  False
# 1816             golden_retriever               0.141736   True
# 253                  Egyptian_cat               0.154914  False
# 1170               cocker_spaniel              0.0620327   True
# 278           Rhodesian_ridgeback              0.0242845   True
# 1858                   Eskimo_dog               0.186789   True
# 918                   toy_terrier  0.0008666069999999999   True
# 142                         crane              0.0847135  False
# 1253                mountain_tent              0.0292033  False
# 136                       whippet              0.0519134   True
# 93                      lampshade             0.00190123  False
# 1457                   otterhound               0.110921   True
# 1594                          pug             0.00765137   True
# 1987              standard_poodle               0.149509   True
# 1376                        teddy               0.155828  False
# 1879              Norfolk_terrier              0.0529553   True
# 1134                   rotisserie              0.0412478  False
# 791                   Maltese_dog    0.08962460000000001   True
# 236               Tibetan_mastiff              0.0633253   True
# 280                         dingo               0.129802  False

# %%
predictions.isnull().sum()
# Out:
# tweet_id    0
# jpg_url     0
# img_num     0
# p1          0
# p1_conf     0
# p1_dog      0
# p2          0
# p2_conf     0
# p2_dog      0
# p3          0
# p3_conf     0
# p3_dog      0
# dtype: int64

# %% [markdown]
# Below is an assessment of the data stored in the **predictions** dataframe.

# %% [markdown]
# **Quality**

# %% [markdown]
# - Column "tweet_id" is of type object. Each tweet_id is a string, when it will be useful to have tweet_id as an int64 object.
#
# - Columns with predictions, i.e "p1_dog","p2_dog", "p3_dog" are also objects. it will be useful to have these objects as a bool (True/False) data type.
#
# - Columns with predicted confidence values p1_conf, p2_conf, p3_conf are also of type object. It will be useful to convert these into float64 data type.

# %% [markdown]
# **Tidiness**

# %% [markdown]
# As far as tidiness is concerned, The predictions dataset is tidy. However, one could argue that columns for the first, second and third prediction outcomes can be molten. It is more convenient to analyze the data as it is.

# %% [markdown]
# ### Clean - Predictions Dataframe

# %%
predictions_copy = predictions.copy()

# %%
predictions_copy["tweet_id"] = predictions_copy["tweet_id"].astype(np.int64)

# %%
predictions_copy["p1_dog"] = predictions_copy["p1_dog"].astype(np.bool)
predictions_copy["p2_dog"] = predictions_copy["p2_dog"].astype(np.bool)

# %%
predictions_copy["p3_dog"] = predictions_copy["p3_dog"].astype(np.bool)

# %%
predictions_copy["p1_conf"] = predictions_copy["p1_conf"].astype(np.float64)
predictions_copy["p2_conf"] = predictions_copy["p2_conf"].astype(np.float64)
predictions_copy["p3_conf"] = predictions_copy["p3_conf"].astype(np.float64)

# %%
predictions = predictions_copy

# %% [markdown]
# ### Master data

# %% [markdown]
# Here we combine our twitter archive data with the data that was retrieved from the Twitter API, the predictions data frame and the mediaURLs dataframe.

# %%
merged = pd.merge(weratedogs_twitter_archive_data,master_df,on="tweet_id",how = "inner")

# %%
merged_2 = pd.merge(merged,predictions,on=["tweet_id"],how="inner")

# %%
merged_master_data = pd.merge(merged_2,mediaURLs,on=["tweet_id"],how="inner")

# %%
merged_master_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2102 entries, 0 to 2101
# Data columns (total 23 columns):
# tweet_id               2102 non-null int64
# timestamp              2102 non-null datetime64[ns]
# source_urls            2102 non-null object
# source_description     2102 non-null object
# text                   2102 non-null object
# standardized_rating    2102 non-null int64
# name                   2102 non-null object
# dog_stage              2102 non-null object
# retweet_count          2102 non-null int64
# favorite_count         2102 non-null int64
# retweeted              2102 non-null bool
# jpg_url                2102 non-null object
# img_num                2102 non-null object
# p1                     2102 non-null object
# p1_conf                2102 non-null float64
# p1_dog                 2102 non-null bool
# p2                     2102 non-null object
# p2_conf                2102 non-null float64
# p2_dog                 2102 non-null bool
# p3                     2102 non-null object
# p3_conf                2102 non-null float64
# p3_dog                 2102 non-null bool
# mediaURL               2102 non-null object
# dtypes: bool(4), datetime64[ns](1), float64(3), int64(4), object(11)
# memory usage: 336.6+ KB

# %%
merged_master_data.to_csv("twitter_archive_master_data.csv",index=False)

# %% [markdown]
# ## Analysis and Visualization of the Final data

# %% [markdown]
# There are plenty of questions to be asked on this dataset to help us analyze this data. I touch upon a few questions on which I later perform the analysis.

# %% [markdown]
# **1. What are some of the words that stand out from the text in the Tweet text?**

# %% [markdown]
# **2. Ratings vs dog-stage: What stages receive a higher rating and which ones receive a lower rating? What can we understand about the distribution of ratings with dog-stages?**

# %% [markdown]
# **3. Do we see a pattern with regards to the number of retweet counts and favorited_counts versus the dog's rating?**

# %% [markdown]
# **4. Dogs with Ratings of the [They're good dogs, Brent](https://knowyourmeme.com/memes/theyre-good-dogs-brent)**

# %% [markdown]
# **5. What are the most common dog names in the dataset?**

# %%
import matplotlib.pyplot as plt

# %%
## Credit to StackOverflow Article: https://stackoverflow.com/a/48750930

from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
stopwords = set(STOPWORDS)

def show_wordcloud(data, title = None, pngfile = "wordcloud.png"):
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        max_words=200,
        max_font_size=40, 
        scale=3,
        random_state=1 # chosen at random by flipping a coin; it was heads
    ).generate(str(data))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    
    plt.savefig(pngfile)
    plt.imshow(wordcloud)
    
    plt.show()
    

stopwords.update(['gets','dog',"Oh"])
#show_wordcloud(Samsung_Reviews_Negative['Reviews'])
show_wordcloud(merged_master_data["text"], title = "WordCloud of the Tweet text")

# %% [markdown]
# Some of the words that appear popular in the dataset are "Mingus" , "Canela", "Jax" (likely dog names). There are also other words such as "Norwegian", "fancy", :cream","pup","Bear"

# %%
merged_master_data.dog_stage.value_counts()
# Out:
# None             1774
# pupper            212
# doggo              71
# puppo              25
# doggo-pupper       11
# floofer             7
# doggo-floofer       1
# doggo-puppo         1
# Name: dog_stage, dtype: int64

# %%
fig,ax = plt.subplots(figsize = (9,9))
plt.title("Distribution of Ratings versus dog_stages")
data = merged_master_data[["tweet_id","standardized_rating","dog_stage"]]
data = data[~data.duplicated()]
data = data[~data["dog_stage"].isin(["None","doggo-puppo","doggo-floofer"])]
data.boxplot(column="standardized_rating",by="dog_stage",ax=ax)
plt.ylabel("Standardized Rating")
plt.savefig("Boxplot1.png")

# %% [markdown]
# Of the different dog stages, it appears that the 'doggo' followed by dogs in the 'puppo' stage on average appears to have a  rating higher than the dogs in the other stages.

# %% [markdown]
# **Does the online community promote or tweet more for dogs with higher ratings?**

# %%
data["standardized_rating"].quantile([0,0.33,0.66,1])
# Out:
# 0.00     3.0
# 0.33    11.0
# 0.66    12.0
# 1.00    27.0
# Name: standardized_rating, dtype: float64

# %%
fig,axes = plt.subplots(3,1, figsize = (9,9))

data = merged_master_data[["tweet_id","retweet_count","favorite_count","standardized_rating"]]
data = data[~data.duplicated()]
bin_edges = [0,8,12,27]
rating_names = ["Poor","Good","Great"]
data["rating_category"] = pd.cut(data["standardized_rating"], bins=bin_edges, labels=rating_names)


for ind,ax in enumerate(axes):
    
    sub_data = data.loc[data["rating_category"] == rating_names[ind]]
    ax.hist(x=sub_data["retweet_count"],bins=20)
    ax.tick_params(axis='x', labelsize=13)
    ax.tick_params(axis="y",labelsize = 13)
    ax.set_title("Distribution of # Retweets for Rating Values: {}-{}".format(str(bin_edges[ind]), str(bin_edges[ind+1])))

plt.subplots_adjust(hspace=0.5,wspace=0.5)
plt.savefig("RetweetDistribution.png")

# %%
fig,axes = plt.subplots(3,1, figsize = (9,9))

for ind,ax in enumerate(axes):
    
    sub_data = data.loc[data["rating_category"] == rating_names[ind]]
    ax.hist(x=sub_data["favorite_count"],bins=50,color='k')
    ax.tick_params(axis='x', labelsize=13)
    ax.tick_params(axis="y",labelsize = 13)
    ax.set_title("Distribution of Like Count for Rating Values: {}-{}".format(str(bin_edges[ind]), str(bin_edges[ind+1])))

plt.subplots_adjust(hspace=0.5,wspace=0.5)
plt.savefig("LikesDistribution.png")

# %% [markdown]
# What are the popular dog breeds that were given a rating more than 10?

# %%
data = merged_master_data[["tweet_id","standardized_rating","p1","p1_conf"]]
data = data[~data.duplicated()]
data["GoodDogs"] = data.standardized_rating > 10

value_counts = data[data["standardized_rating"] > 10].p1.value_counts()
top_5_dogs = value_counts[:5]
fig,ax = plt.subplots(figsize=(10,10))

top_5_dogs.plot(kind="bar",ax=ax,width = 0.4)
ax.set_ylabel("# of Ratings above 10",fontsize = 13)
ax.set_title("Top 5 Predicted Dog breeds that have most ratings above 10",fontsize=13)
ax.tick_params(axis='x', labelsize=13)
ax.tick_params(axis="y",labelsize = 13)
plt.savefig("Top5Dogbreeds.png")

# %% [markdown]
# **Common Dog names in the dataset**

# %%
data = merged_master_data[["tweet_id","name"]]
data = data[~data.duplicated()]
data = data[~data.name.isin(["None","a"])]
show_wordcloud(data["name"],title="Common Names",pngfile="common_names_wordcloud.png")

# %% [markdown]
# Some of the most common dog names appear to be Oliver, Cooper, Lucy, Charlier, Tucker, Penny.

# %%
data.name.value_counts()
# Out:
# Oliver       10
# Lucy         10
# Penny        10
# Cooper       10
# Charlie      10
# Tucker       10
# Winston       8
# Bo            8
# Sadie         8
# Lola          8
# the           7
# Toby          7
# an            7
# Daisy         7
# Stanley       6
# Bailey        6
# Scout         6
# Milo          6
# Bella         6
# Koda          6
# Jax           6
# Rusty         6
# Dave          6
# Chester       5
# Oscar         5
# Leo           5
# Larry         5
# Buddy         5
# Louis         5
# Alfie         5
#              ..
# Divine        1
# Huxley        1
# Remy          1
# Scruffers     1
# Ben           1
# Geoff         1
# Sojourner     1
# Callie        1
# Creg          1
# Gin           1
#  Forrest      1
# Willem        1
# Pinot         1
# Damon         1
# Carly         1
# Lilli         1
# Ito           1
# Franq         1
# Rumpole       1
# Clybe         1
# Strudel       1
# Bradlay       1
# Ridley        1
# Aqua          1
# Baron         1
# Brian         1
# Arlo          1
# Mark          1
# Donny         1
# Glacier       1
# Name: name, Length: 952, dtype: int64
